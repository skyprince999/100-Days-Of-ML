# %% [markdown]
# We use [RAPIDS](https://rapids.ai/) for clustering faces in the train dataset. Rapids is a package developed and maintained by NVidia and uses the GPU for fast calculations
#
# The faces were cropped using the facenet's pytorch version. They are 160x160 in dimension. Sample 2000(aprox) images can be found in the following [dataset](https://www.kaggle.com/skylord/sample-face-crop)
#
# Inspiration is taken :) from the following awesome notebooks:
#
# - @Bojan's MNIST 2-D t-sne with rapids: [Link](https://www.kaggle.com/tunguz/mnist-2d-t-sne-with-rapids)
# - @Henrique's Proper clustering with facenet embeddings + PCA: [Link](https://www.kaggle.com/hmendonca/proper-clustering-with-facenet-embeddings-eda/)
#
#
#
# So who is the fastest!
# ![FastestSuperHero](https://www.kaggle.com/skylord/sample-face-crop#best-flash-super-hero-dc-laser-time.jpg)

# %%
# %%time
# We add the rapids kaggle dataset [Link](https://www.kaggle.com/cdeotte/rapids)
# This installs the package offline. Installation takes place under a minute! 
import sys
# !cp ../input/rapids/rapids.0.11.0 /opt/conda/envs/rapids.tar.gz
# !cd /opt/conda/envs/ && tar -xzvf rapids.tar.gz
sys.path = ["/opt/conda/envs/rapids/lib"] + ["/opt/conda/envs/rapids/lib/python3.6"] + ["/opt/conda/envs/rapids/lib/python3.6/site-packages"] + sys.path
# !cp /opt/conda/envs/rapids/lib/libxgboost.so /opt/conda/lib/
# Out:
# rapids/
# rapids/bin/
# rapids/bin/msgunfmt
# rapids/bin/pyvenv
# rapids/bin/msgen
# rapids/bin/djpeg
# rapids/bin/gdaltindex
# rapids/bin/gss-client
# rapids/bin/png-fix-itxt
# rapids/bin/python3-config
# rapids/bin/gif2rgb
# rapids/bin/ncgen
# rapids/bin/gdal-config
# rapids/bin/PParse
# rapids/bin/xzdec
# rapids/bin/numba
# rapids/bin/SAX2Count
# rapids/bin/h5unjam
# rapids/bin/glib-gettextize
# rapids/bin/fc-list
# rapids/bin/xzgrep
# rapids/bin/giftool
# rapids/bin/grpc_python_plugin
# rapids/bin/k5srvutil
# rapids/bin/gifbuild
# rapids/bin/gflags_completions.sh
# rapids/bin/uuclient
# rapids/bin/gio-querymodules
# rapids/bin/dask-ssh
# rapids/bin/msguniq
# rapids/bin/lz4c
# rapids/bin/ncdump
# rapids/bin/vacuumlo
# rapids/bin/bzfgrep
# rapids/bin/ngettext
# rapids/bin/gdal_sieve.py
# rapids/bin/gdalsrsinfo
# rapids/bin/2to3-3.6
# rapids/bin/lzdiff
# rapids/bin/pg_receivewal
# rapids/bin/rdjpgcom
# rapids/bin/gnmanalyse
# rapids/bin/pyvenv-3.6
# rapids/bin/ktutil
# rapids/bin/invproj
# rapids/bin/pgbench
# rapids/bin/protoc
# rapids/bin/vacuumdb
# rapids/bin/hdf24to8
# rapids/bin/bzcat
# rapids/bin/pg_resetwal
# rapids/bin/reindexdb
# rapids/bin/grpc_objective_c_plugin
# rapids/bin/gdaladdo
# rapids/bin/curl-config
# rapids/bin/ecpg
# rapids/bin/gdal_proximity.py
# rapids/bin/pcretest
# rapids/bin/bzdiff
# rapids/bin/hdftor8
# rapids/bin/grpc_cpp_plugin
# rapids/bin/gcps2wld.py
# rapids/bin/infocmp
# rapids/bin/opj_decompress
# rapids/bin/cs2cs
# rapids/bin/ncgen3
# rapids/bin/gdal2xyz.py
# rapids/bin/pydoc
# rapids/bin/lzfgrep
# rapids/bin/ncurses6-config
# rapids/bin/zdump
# rapids/bin/pg_waldump
# rapids/bin/zstdmt
# rapids/bin/gdal2tiles.py
# rapids/bin/hdftopal
# rapids/bin/pydoc3.6
# rapids/bin/xgboost
# rapids/bin/grpc_node_plugin
# rapids/bin/lzcat
# rapids/bin/msggrep
# rapids/bin/fastavro
# rapids/bin/ppm2tiff
# rapids/bin/plasma-store-server
# rapids/bin/glib-compile-resources
# rapids/bin/gdal_calc.py
# rapids/bin/fc-match
# rapids/bin/sclient
# rapids/bin/pdfdetach
# rapids/bin/EnumVal
# rapids/bin/gendict
# rapids/bin/pdffonts
# rapids/bin/hdfpack
# rapids/bin/gdbus
# rapids/bin/envsubst
# rapids/bin/gio-launch-desktop
# rapids/bin/grpc_php_plugin
# rapids/bin/geotifcp
# rapids/bin/gdalcompare.py
# rapids/bin/gdalenhance
# rapids/bin/wish
# rapids/bin/pcre-config
# rapids/bin/sim_client
# rapids/bin/icuinfo
# rapids/bin/brotli
# rapids/bin/clusterdb
# rapids/bin/gifinto
# rapids/bin/pct2rgb.py
# rapids/bin/jpeg2hdf
# rapids/bin/python3.6m
# rapids/bin/grpc_ruby_plugin
# rapids/bin/xzmore
# rapids/bin/jpegtran
# rapids/bin/pg_controldata
# rapids/bin/msgcat
# rapids/bin/tiffcmp
# rapids/bin/bzip2recover
# rapids/bin/zstdcat
# rapids/bin/genbrk
# rapids/bin/h4_ncgen
# rapids/bin/dap-config-pkgconfig
# rapids/bin/tiffmedian
# rapids/bin/grpc_csharp_plugin
# rapids/bin/DOMCount
# rapids/bin/zstdless
# rapids/bin/esri2wkt.py
# rapids/bin/geos-config
# rapids/bin/pkgdata
# rapids/bin/SEnumVal
# rapids/bin/msgfmt
# rapids/bin/tput
# rapids/bin/glib-genmarshal
# rapids/bin/gifclrmp
# rapids/bin/hdp
# rapids/bin/hdfcomp
# rapids/bin/gie
# rapids/bin/msgexec
# rapids/bin/postgres
# rapids/bin/pg_config
# rapids/bin/gtester
# rapids/bin/xzcat
# rapids/bin/python3.6
# rapids/bin/zstdgrep
# rapids/bin/tiffsplit
# rapids/bin/acountry
# rapids/bin/gdaltransform
# rapids/bin/gencnval
# rapids/bin/gdal_rasterize
# rapids/bin/SAX2Print
# rapids/bin/zic
# rapids/bin/pdftops
# rapids/bin/pg_recvlogical
# rapids/bin/giftext
# rapids/bin/lz4
# rapids/bin/h5jam
# rapids/bin/gettext.sh
# rapids/bin/gdal_edit.py
# rapids/bin/getdap4
# rapids/bin/msginit
# rapids/bin/h5stat
# rapids/bin/tclsh8.6
# rapids/bin/hdfunpac
# rapids/bin/dask-scheduler
# rapids/bin/gsettings
# rapids/bin/python3
# rapids/bin/gdal_pansharpen.py
# rapids/bin/sqlite3
# rapids/bin/applygeo
# rapids/bin/nc-config
# rapids/bin/SAXPrint
# rapids/bin/h52gif
# rapids/bin/tiffcp
# rapids/bin/mock
# rapids/bin/gdal_merge.py
# rapids/bin/Redirect
# rapids/bin/CreateDOMDocument
# rapids/bin/autopoint
# rapids/bin/gobject-query
# rapids/bin/xmlcatalog
# rapids/bin/gdal_translate
# rapids/bin/h5debug
# rapids/bin/ogrinfo
# rapids/bin/lzmore
# rapids/bin/hdf8to24
# rapids/bin/xzfgrep
# rapids/bin/derb
# rapids/bin/pg_checksums
# rapids/bin/gifecho
# rapids/bin/StdInParse
# rapids/bin/h5perf_serial
# rapids/bin/giffilter
# rapids/bin/h4_ncdump
# rapids/bin/gdalmanage
# rapids/bin/gdalbuildvrt
# rapids/bin/gdallocationinfo
# rapids/bin/createdb
# rapids/bin/listgeo
# rapids/bin/reset
# rapids/bin/opj_compress
# rapids/bin/f2py3
# rapids/bin/pg_test_timing
# rapids/bin/lzless
# rapids/bin/tiff2rgba
# rapids/bin/gdalident.py
# rapids/bin/ncursesw6-config
# rapids/bin/xmlwf
# rapids/bin/fc-pattern
# rapids/bin/kdestroy
# rapids/bin/xzegrep
# rapids/bin/tiff2bw
# rapids/bin/pdfimages
# rapids/bin/compile_et
# rapids/bin/dap-config
# rapids/bin/pip
# rapids/bin/f2py3.6
# rapids/bin/fc-cat
# rapids/bin/pdftoppm
# rapids/bin/msgfilter
# rapids/bin/kpasswd
# rapids/bin/lz4cat
# rapids/bin/h5redeploy
# rapids/bin/pg_basebackup
# rapids/bin/hdf2jpeg
# rapids/bin/pg_upgrade
# rapids/bin/hdfls
# rapids/bin/cygdb
# rapids/bin/klist
# rapids/bin/gtester-report
# rapids/bin/gettextize
# rapids/bin/icu-config
# rapids/bin/ksu
# rapids/bin/gdalimport.py
# rapids/bin/tic
# rapids/bin/gapplication
# rapids/bin/cythonize
# rapids/bin/gdalmove.py
# rapids/bin/kea-config
# rapids/bin/funpack
# rapids/bin/ahost
# rapids/bin/invgeod
# rapids/bin/msgconv
# rapids/bin/adig
# rapids/bin/tiffdither
# rapids/bin/bzcmp
# rapids/bin/MemParse
# rapids/bin/cct
# rapids/bin/cjpeg
# rapids/bin/createuser
# rapids/bin/xml2-config
# rapids/bin/fc-scan
# rapids/bin/psql
# rapids/bin/cairo-trace
# rapids/bin/unlz4
# rapids/bin/epsg_tr.py
# rapids/bin/iconv
# rapids/bin/tiffcrop
# rapids/bin/openssl
# rapids/bin/opj_dump
# rapids/bin/pdfunite
# rapids/bin/h5format_convert
# rapids/bin/hdfed
# rapids/bin/kvno
# rapids/bin/ristosds
# rapids/bin/xgettext
# rapids/bin/kinit
# rapids/bin/zstd
# rapids/bin/pg_archivecleanup
# rapids/bin/PSVIWriter
# rapids/bin/gdalserver
# rapids/bin/genrb
# rapids/bin/hdfimport
# rapids/bin/gio
# rapids/bin/unzstd
# rapids/bin/wheel
# rapids/bin/fc-query
# rapids/bin/giffix
# rapids/bin/initdb
# rapids/bin/makeconv
# rapids/bin/fc-cache
# rapids/bin/infotocap
# rapids/bin/dask-cuda-worker
# rapids/bin/vmake
# rapids/bin/unlzma
# rapids/bin/SCMPrint
# rapids/bin/pg_isready
# rapids/bin/idle3.6
# rapids/bin/h5repack
# rapids/bin/gdal_contour
# rapids/bin/fitscopy
# rapids/bin/h5ls
# rapids/bin/curl
# rapids/bin/glib-compile-schemas
# rapids/bin/dropdb
# rapids/bin/getdap
# rapids/bin/xz
# rapids/bin/rgb2pct.py
# rapids/bin/ogr2ogr
# rapids/bin/lzgrep
# rapids/bin/hdiff
# rapids/bin/h5clear
# rapids/bin/plasma_store
# rapids/bin/msgcomm
# rapids/bin/imcopy
# rapids/bin/pg_test_fsync
# rapids/bin/unxz
# rapids/bin/gdal_fillnodata.py
# rapids/bin/fc-validate
# rapids/bin/xzless
# rapids/bin/gif2hdf
# rapids/bin/SAXCount
# rapids/bin/toe
# rapids/bin/kswitch
# rapids/bin/pcregrep
# rapids/bin/cython
# rapids/bin/h5cc
# rapids/bin/libpng-config
# rapids/bin/msgcmp
# rapids/bin/bzgrep
# rapids/bin/lzmainfo
# rapids/bin/gdaldem
# rapids/bin/nccopy
# rapids/bin/gdbus-codegen
# rapids/bin/tiffinfo
# rapids/bin/wish8.6
# rapids/bin/gresource
# rapids/bin/pdfinfo
# rapids/bin/makegeo
# rapids/bin/testepsg
# rapids/bin/ogrlineref
# rapids/bin/pdftotext
# rapids/bin/h5mkgrp
# rapids/bin/oid2name
# rapids/bin/tclsh
# rapids/bin/xmllint
# rapids/bin/lzcmp
# rapids/bin/proj
# rapids/bin/2to3
# rapids/bin/hrepack
# rapids/bin/bzip2
# rapids/bin/ogrtindex
# rapids/bin/h4cc
# rapids/bin/h5dump
# rapids/bin/gifsponge
# rapids/bin/h5import
# rapids/bin/xzdiff
# rapids/bin/freetype-config
# rapids/bin/python3.6m-config
# rapids/bin/tiffset
# rapids/bin/pg_restore
# rapids/bin/bzmore
# rapids/bin/tzselect
# rapids/bin/recode-sr-latin
# rapids/bin/idle3
# rapids/bin/vshow
# rapids/bin/gdalinfo
# rapids/bin/clear
# rapids/bin/fc-conflist
# rapids/bin/gdal_auth.py
# rapids/bin/gif2h5
# rapids/bin/wrjpgcom
# rapids/bin/h5c++
# rapids/bin/paltohdf
# rapids/bin/pg_dump
# rapids/bin/easy_install
# rapids/bin/gdalchksum.py
# rapids/bin/mkgraticule.py
# rapids/bin/fax2ps
# rapids/bin/projinfo
# rapids/bin/fpack
# rapids/bin/pycc
# rapids/bin/fax2tiff
# rapids/bin/bzegrep
# rapids/bin/bzless
# rapids/bin/krb5-config
# rapids/bin/pdftohtml
# rapids/bin/xzcmp
# rapids/bin/c_rehash
# rapids/bin/XInclude
# rapids/bin/lzmadec
# rapids/bin/python3.6-config
# rapids/bin/pal2rgb
# rapids/bin/gdalwarp
# rapids/bin/bokeh
# rapids/bin/h5repart
# rapids/bin/pdfseparate
# rapids/bin/f2py
# rapids/bin/gdal_polygonize.py
# rapids/bin/smem
# rapids/bin/tiffdump
# rapids/bin/gdal_retile.py
# rapids/bin/msgattrib
# rapids/bin/h4redeploy
# rapids/bin/thrift
# rapids/bin/msgmerge
# rapids/bin/tiff2ps
# rapids/bin/libpng16-config
# rapids/bin/dropuser
# rapids/bin/r8tohdf
# rapids/bin/tset
# rapids/bin/tabs
# rapids/bin/gnmmanage
# rapids/bin/nearblack
# rapids/bin/gettext
# rapids/bin/DOMPrint
# rapids/bin/pydoc3
# rapids/bin/lzma
# rapids/bin/pg_dumpall
# rapids/bin/pg_standby
# rapids/bin/h5watch
# rapids/bin/python
# rapids/bin/raw2tiff
# rapids/bin/postmaster
# rapids/bin/ogrmerge.py
# rapids/bin/glib-mkenums
# rapids/bin/h5copy
# rapids/bin/geod
# rapids/bin/captoinfo
# rapids/bin/gencfu
# rapids/bin/pdftocairo
# rapids/bin/h5fc
# rapids/bin/bunzip2
# rapids/bin/pngfix
# rapids/bin/lzegrep
# rapids/bin/pg_ctl
# rapids/bin/gcps2vec.py
# rapids/bin/hdf2gif
# rapids/bin/h5diff
# rapids/bin/dask-worker
# rapids/bin/tiff2pdf
# rapids/bin/gdal_grid
# rapids/bin/pg_rewind
# rapids/bin/sqlite3_analyzer
# rapids/bin/kadmin
# rapids/var/
# rapids/var/cache/
# rapids/var/cache/fontconfig/
# rapids/var/cache/fontconfig/.leave
# rapids/etc/
# rapids/etc/localtime
# rapids/etc/conda/
# rapids/etc/conda/deactivate.d/
# rapids/etc/conda/deactivate.d/geotiff-deactivate.sh
# rapids/etc/conda/deactivate.d/proj4-deactivate.sh
# rapids/etc/conda/deactivate.d/proj4-deactivate.fish
# rapids/etc/conda/deactivate.d/gdal-deactivate.sh
# rapids/etc/conda/deactivate.d/proj4-deactivate.csh
# rapids/etc/conda/activate.d/
# rapids/etc/conda/activate.d/gdal-activate.sh
# rapids/etc/conda/activate.d/proj4-activate.fish
# rapids/etc/conda/activate.d/proj4-activate.sh
# rapids/etc/conda/activate.d/proj4-activate.csh
# rapids/etc/conda/activate.d/geotiff-activate.sh
# rapids/etc/fonts/
# rapids/etc/fonts/fonts.conf
# rapids/etc/fonts/conf.d/
# rapids/etc/fonts/conf.d/65-nonlatin.conf
# rapids/etc/fonts/conf.d/60-generic.conf
# rapids/etc/fonts/conf.d/65-fonts-persian.conf
# rapids/etc/fonts/conf.d/30-metric-aliases.conf
# rapids/etc/fonts/conf.d/README
# rapids/etc/fonts/conf.d/80-delicious.conf
# rapids/etc/fonts/conf.d/60-latin.conf
# rapids/etc/fonts/conf.d/51-local.conf
# rapids/etc/fonts/conf.d/45-latin.conf
# rapids/etc/fonts/conf.d/40-nonlatin.conf
# rapids/etc/fonts/conf.d/10-scale-bitmap-fonts.conf
# rapids/etc/fonts/conf.d/69-unifont.conf
# rapids/etc/fonts/conf.d/45-generic.conf
# rapids/etc/fonts/conf.d/90-synthetic.conf
# rapids/etc/fonts/conf.d/49-sansserif.conf
# rapids/etc/fonts/conf.d/20-unhint-small-vera.conf
# rapids/etc/fonts/conf.d/10-hinting-slight.conf
# rapids/etc/fonts/conf.d/50-user.conf
# rapids/conda-meta/
# rapids/conda-meta/libprotobuf-3.8.0-h8b12597_0.json
# rapids/conda-meta/curl-7.68.0-hf8cf82a_0.json
# rapids/conda-meta/libtiff-4.1.0-hfc65ed5_0.json
# rapids/conda-meta/pip-20.0.2-py_2.json
# rapids/conda-meta/msgpack-python-0.6.2-py36hc9558a2_0.json
# rapids/conda-meta/pynvml-8.0.4-py_0.json
# rapids/conda-meta/cugraph-0.11.0-py36_0.json
# rapids/conda-meta/xorg-xproto-7.0.31-h14c3975_1007.json
# rapids/conda-meta/fsspec-0.6.2-py_0.json
# rapids/conda-meta/numba-0.46.0-py36hb3f55d8_1.json
# rapids/conda-meta/lz4-c-1.8.3-he1b5a44_1001.json
# rapids/conda-meta/xerces-c-3.2.2-h8412b87_1004.json
# rapids/conda-meta/libiconv-1.15-h516909a_1005.json
# rapids/conda-meta/krb5-1.16.4-h2fd8d38_0.json
# rapids/conda-meta/c-ares-1.15.0-h516909a_1001.json
# rapids/conda-meta/rapids-0.11.0-cuda10.1_py36_10.json
# rapids/conda-meta/jinja2-2.11.1-py_0.json
# rapids/conda-meta/thrift-cpp-0.12.0-hf3afdfd_1004.json
# rapids/conda-meta/cupy-6.7.0-py36h0c141eb_1.json
# rapids/conda-meta/openjpeg-2.3.1-h981e76c_3.json
# rapids/conda-meta/markupsafe-1.1.1-py36h516909a_0.json
# rapids/conda-meta/llvmlite-0.30.0-py36h8b12597_1.json
# rapids/conda-meta/json-c-0.13.1-h14c3975_1001.json
# rapids/conda-meta/libedit-3.1.20170329-hf8c457e_1001.json
# rapids/conda-meta/dask-2.10.1-py_0.json
# rapids/conda-meta/poppler-0.67.0-h14e79db_8.json
# rapids/conda-meta/proj-6.3.0-hc80f0dc_0.json
# rapids/conda-meta/postgresql-12.1-hc63931a_0.json
# rapids/conda-meta/cudnn-7.6.0-cuda10.1_0.json
# rapids/conda-meta/xz-5.2.4-h14c3975_1001.json
# rapids/conda-meta/libcuml-0.11.0-cuda10.1_0.json
# rapids/conda-meta/py-xgboost-1.0.0dev.rapidsai0.11-cuda10.1py36_1.json
# rapids/conda-meta/partd-1.1.0-py_0.json
# rapids/conda-meta/pillow-7.0.0-py36hefe7db6_0.json
# rapids/conda-meta/re2-2020.01.01-he1b5a44_0.json
# rapids/conda-meta/yaml-0.2.2-h516909a_1.json
# rapids/conda-meta/geotiff-1.5.1-h38872f0_8.json
# rapids/conda-meta/rmm-0.11.0-py36_0.json
# rapids/conda-meta/zstd-1.4.3-h3b9ef0a_0.json
# rapids/conda-meta/uriparser-0.9.3-he1b5a44_1.json
# rapids/conda-meta/libpng-1.6.37-hed695b0_0.json
# rapids/conda-meta/libstdcxx-ng-9.2.0-hdf63c60_2.json
# rapids/conda-meta/libcumlprims-0.11.0-cuda10.1_0.json
# rapids/conda-meta/bokeh-1.4.0-py36_0.json
# rapids/conda-meta/scipy-1.4.1-py36h921218d_0.json
# rapids/conda-meta/libuuid-2.32.1-h14c3975_1000.json
# rapids/conda-meta/wheel-0.34.2-py_1.json
# rapids/conda-meta/kealib-1.4.10-h58c409b_1005.json
# rapids/conda-meta/cudatoolkit-10.1.243-h6bb024c_0.json
# rapids/conda-meta/libgomp-9.2.0-h24d8f2e_2.json
# rapids/conda-meta/numpy-1.18.1-py36h95a1406_0.json
# rapids/conda-meta/xorg-libsm-1.2.3-h84519dc_1000.json
# rapids/conda-meta/gdal-2.4.4-py36h5f563d9_0.json
# rapids/conda-meta/xorg-xextproto-7.3.0-h14c3975_1002.json
# rapids/conda-meta/psutil-5.6.7-py36h516909a_0.json
# rapids/conda-meta/readline-8.0-hf8c457e_0.json
# rapids/conda-meta/xorg-libxdmcp-1.1.3-h516909a_0.json
# rapids/conda-meta/gflags-2.2.2-he1b5a44_1002.json
# rapids/conda-meta/libxcb-1.13-h14c3975_1002.json
# rapids/conda-meta/dask-cudf-0.11.0-py36_0.json
# rapids/conda-meta/tzcode-2019a-h516909a_1002.json
# rapids/conda-meta/libxml2-2.9.10-hee79883_0.json
# rapids/conda-meta/cuspatial-0.11.0-py36_0.json
# rapids/conda-meta/arrow-cpp-0.15.0-py36h090bef1_2.json
# rapids/conda-meta/cudf-0.11.0-py36_0.json
# rapids/conda-meta/liblapack-3.8.0-14_openblas.json
# rapids/conda-meta/libevent-2.1.10-h72c5cf5_0.json
# rapids/conda-meta/libcurl-7.68.0-hda55be3_0.json
# rapids/conda-meta/expat-2.2.9-he1b5a44_2.json
# rapids/conda-meta/giflib-5.1.7-h516909a_1.json
# rapids/conda-meta/pyarrow-0.15.0-py36h8b68381_1.json
# rapids/conda-meta/libgfortran-ng-7.3.0-hdf63c60_5.json
# rapids/conda-meta/libspatialite-4.3.0a-ha48a99a_1034.json
# rapids/conda-meta/distributed-2.10.0-py_0.json
# rapids/conda-meta/hdf5-1.10.5-nompi_h3c11f04_1104.json
# rapids/conda-meta/zlib-1.2.11-h516909a_1006.json
# rapids/conda-meta/sortedcontainers-2.1.0-py_0.json
# rapids/conda-meta/pyyaml-5.3-py36h516909a_0.json
# rapids/conda-meta/xorg-renderproto-0.11.1-h14c3975_1002.json
# rapids/conda-meta/certifi-2019.11.28-py36_0.json
# rapids/conda-meta/pandas-0.24.2-py36hb3f55d8_1.json
# rapids/conda-meta/xorg-libxrender-0.9.10-h516909a_1002.json
# rapids/conda-meta/pyparsing-2.4.6-py_0.json
# rapids/conda-meta/grpc-cpp-1.23.0-h18db393_0.json
# rapids/conda-meta/cairo-1.16.0-hfb77d84_1002.json
# rapids/conda-meta/dask-core-2.10.1-py_0.json
# rapids/conda-meta/fastavro-0.22.9-py36h516909a_0.json
# rapids/conda-meta/poppler-data-0.4.9-1.json
# rapids/conda-meta/libgdal-2.4.4-h2b6fda6_0.json
# rapids/conda-meta/xorg-libice-1.0.10-h516909a_0.json
# rapids/conda-meta/xorg-libxau-1.0.9-h14c3975_0.json
# rapids/conda-meta/libblas-3.8.0-14_openblas.json
# rapids/conda-meta/_libgcc_mutex-0.1-conda_forge.json
# rapids/conda-meta/libffi-3.2.1-he1b5a44_1006.json
# rapids/conda-meta/python-3.6.7-h357f687_1006.json
# rapids/conda-meta/six-1.14.0-py36_0.json
# rapids/conda-meta/xorg-libx11-1.6.9-h516909a_0.json
# rapids/conda-meta/dlpack-0.2-he1b5a44_1.json
# rapids/conda-meta/glib-2.58.3-py36h6f030ca_1002.json
# rapids/conda-meta/pixman-0.38.0-h516909a_1003.json
# rapids/conda-meta/history
# rapids/conda-meta/double-conversion-3.1.5-he1b5a44_2.json
# rapids/conda-meta/tk-8.6.10-hed695b0_0.json
# rapids/conda-meta/cfitsio-3.470-hb60a0a2_2.json
# rapids/conda-meta/python-dateutil-2.8.1-py_0.json
# rapids/conda-meta/cloudpickle-1.2.2-py_1.json
# rapids/conda-meta/libkml-1.3.0-h4fcabce_1010.json
# rapids/conda-meta/xorg-libxext-1.3.4-h516909a_0.json
# rapids/conda-meta/boost-cpp-1.70.0-h8e57a91_2.json
# rapids/conda-meta/snappy-1.1.8-he1b5a44_1.json
# rapids/conda-meta/brotli-1.0.7-he1b5a44_1000.json
# rapids/conda-meta/libcblas-3.8.0-14_openblas.json
# rapids/conda-meta/libdap4-3.20.4-hd3bb157_0.json
# rapids/conda-meta/libllvm8-8.0.1-hc9558a2_0.json
# rapids/conda-meta/nvstrings-0.11.0-py36_0.json
# rapids/conda-meta/click-7.0-py_0.json
# rapids/conda-meta/libpq-12.1-hd9ab2ff_0.json
# rapids/conda-meta/rapids-xgboost-0.11.0-cuda10.1_py36_10.json
# rapids/conda-meta/libssh2-1.8.2-h22169c7_2.json
# rapids/conda-meta/sqlite-3.30.1-hcee41ef_0.json
# rapids/conda-meta/freetype-2.10.0-he983fc9_1.json
# rapids/conda-meta/toolz-0.10.0-py_0.json
# rapids/conda-meta/dask-cuda-0.11.0-py36_0.json
# rapids/conda-meta/cython-0.29.14-py36he1b5a44_0.json
# rapids/conda-meta/scikit-learn-0.22.1-py36hcdab131_1.json
# rapids/conda-meta/locket-0.2.0-py_2.json
# rapids/conda-meta/geos-3.8.0-he1b5a44_0.json
# rapids/conda-meta/fontconfig-2.13.1-h86ecdb6_1001.json
# rapids/conda-meta/packaging-20.1-py_0.json
# rapids/conda-meta/libnetcdf-4.7.3-nompi_h9f9fd6a_101.json
# rapids/conda-meta/bzip2-1.0.8-h516909a_2.json
# rapids/conda-meta/libopenblas-0.3.7-h5ec1e0e_6.json
# rapids/conda-meta/gettext-0.19.8.1-hc5be6a0_1002.json
# rapids/conda-meta/libgcc-ng-9.2.0-h24d8f2e_2.json
# rapids/conda-meta/pytz-2019.3-py_0.json
# rapids/conda-meta/cuml-0.11.0-cuda10.1_py36_0.json
# rapids/conda-meta/nccl-2.4.6.1-cuda10.1_0.json
# rapids/conda-meta/pcre-8.43-he1b5a44_0.json
# rapids/conda-meta/libcuspatial-0.11.0-cuda10.1_0.json
# rapids/conda-meta/glog-0.4.0-he1b5a44_1.json
# rapids/conda-meta/pthread-stubs-0.4-h14c3975_1001.json
# rapids/conda-meta/librmm-0.11.0-cuda10.1_0.json
# rapids/conda-meta/hdf4-4.2.13-hf30be14_1003.json
# rapids/conda-meta/parquet-cpp-1.5.1-2.json
# rapids/conda-meta/jpeg-9c-h14c3975_1001.json
# rapids/conda-meta/xorg-kbproto-1.0.7-h14c3975_1002.json
# rapids/conda-meta/olefile-0.46-py_0.json
# rapids/conda-meta/ncurses-6.1-hf484d3e_1002.json
# rapids/conda-meta/tornado-6.0.3-py36h516909a_0.json
# rapids/conda-meta/zict-1.0.0-py_0.json
# rapids/conda-meta/cytoolz-0.10.1-py36h516909a_0.json
# rapids/conda-meta/openssl-1.1.1d-h516909a_0.json
# rapids/conda-meta/libcudf-0.11.0-cuda10.1_0.json
# rapids/conda-meta/freexl-1.0.5-h14c3975_1002.json
# rapids/conda-meta/heapdict-1.0.1-py_0.json
# rapids/conda-meta/xgboost-1.0.0dev.rapidsai0.11-cuda10.1py36_1.json
# rapids/conda-meta/ca-certificates-2019.11.28-hecc5488_0.json
# rapids/conda-meta/_openmp_mutex-4.5-0_gnu.json
# rapids/conda-meta/fastrlock-0.4-py36he1b5a44_1000.json
# rapids/conda-meta/tblib-1.6.0-py_0.json
# rapids/conda-meta/libxgboost-1.0.0dev.rapidsai0.11-cuda10.1_1.json
# rapids/conda-meta/icu-64.2-he1b5a44_1.json
# rapids/conda-meta/joblib-0.14.1-py_0.json
# rapids/conda-meta/libnvstrings-0.11.0-cuda10.1_0.json
# rapids/conda-meta/libcugraph-0.11.0-cuda10.1_0.json
# rapids/conda-meta/dask-xgboost-0.2.0.dev28-cuda10.1py36_0.json
# rapids/conda-meta/setuptools-45.1.0-py36_0.json
# rapids/lib/
# rapids/lib/libboost_math_tr1.so.1.70
# rapids/lib/libdapclient.so.6.1.11
# rapids/lib/libkadm5clnt.so
# rapids/lib/libgobject-2.0.so.0.5800.3
# rapids/lib/libkrb5support.so.0.1
# rapids/lib/libpgport.a
# rapids/lib/libcumlprims.so
# rapids/lib/libiconv.so.2
# rapids/lib/latin2_and_win1250.so
# rapids/lib/libproj.so.15.3.0
# rapids/lib/libxcb-xf86dri.so.0
# rapids/lib/libxcb-xinput.so.0.1.0
# rapids/lib/libnccl.so
# rapids/lib/libxcb-shm.so.0
# rapids/lib/libXrender.so.1.3.0
# rapids/lib/libdf.so.0
# rapids/lib/libexpat.so.1
# rapids/lib/libpanelw.so.6
# rapids/lib/libicuio.so.64
# rapids/lib/libboost_log_setup.so.1
# rapids/lib/pgxs/
# rapids/lib/pgxs/src/
# rapids/lib/pgxs/src/makefiles/
# rapids/lib/pgxs/src/makefiles/pgxs.mk
# rapids/lib/pgxs/src/Makefile.global
# rapids/lib/pgxs/src/test/
# rapids/lib/pgxs/src/test/regress/
# rapids/lib/pgxs/src/test/regress/pg_regress
# rapids/lib/pgxs/src/Makefile.port
# rapids/lib/pgxs/src/Makefile.shlib
# rapids/lib/pgxs/src/nls-global.mk
# rapids/lib/pgxs/config/
# rapids/lib/pgxs/config/missing
# rapids/lib/pgxs/config/install-sh
# rapids/lib/libevent_openssl.so
# rapids/lib/libsqlite3.so
# rapids/lib/engines-1.1/
# rapids/lib/engines-1.1/capi.so
# rapids/lib/engines-1.1/afalg.so
# rapids/lib/engines-1.1/padlock.so
# rapids/lib/libgettextlib-0.19.8.1.so
# rapids/lib/libhdf5_cpp.so.103.1.0
# rapids/lib/libxcb-xvmc.so.0.0.0
# rapids/lib/libboost_log.a
# rapids/lib/libxcb-sync.so.1.0.0
# rapids/lib/libcares.so
# rapids/lib/libproj.so
# rapids/lib/libX11-xcb.so.1.0.0
# rapids/lib/libnvvm.so.3.3.0
# rapids/lib/libthriftz.so.0.12.0
# rapids/lib/libboost_math_c99.so.1.70.0
# rapids/lib/libboost_date_time.so.1.70
# rapids/lib/libboost_stacktrace_addr2line.so
# rapids/lib/libopenjp2.a
# rapids/lib/libcrypto.so
# rapids/lib/libXau.so
# rapids/lib/libkrb5.so.3.3
# rapids/lib/libboost_math_c99.so
# rapids/lib/libkrb5.so
# rapids/lib/libgflags.a
# rapids/lib/libtclstub8.6.a
# rapids/lib/liblz4.so.1
# rapids/lib/libblas.so.3
# rapids/lib/libboost_math_c99f.a
# rapids/lib/libiconv.so
# rapids/lib/libk5crypto.so.3.1
# rapids/lib/libverto.so
# rapids/lib/libxcb-shape.so.0
# rapids/lib/libkea.so.1.4
# rapids/lib/libicudata.so.64
# rapids/lib/libboost_atomic.so.1
# rapids/lib/libpixman-1.so
# rapids/lib/libboost_coroutine.so.1
# rapids/lib/libecpg.a
# rapids/lib/tcl8.6/
# rapids/lib/tcl8.6/clock.tcl
# rapids/lib/tcl8.6/package.tcl
# rapids/lib/tcl8.6/encoding/
# rapids/lib/tcl8.6/encoding/macGreek.enc
# rapids/lib/tcl8.6/encoding/gb1988.enc
# rapids/lib/tcl8.6/encoding/iso8859-3.enc
# rapids/lib/tcl8.6/encoding/symbol.enc
# rapids/lib/tcl8.6/encoding/iso8859-8.enc
# rapids/lib/tcl8.6/encoding/cp437.enc
# rapids/lib/tcl8.6/encoding/iso8859-7.enc
# rapids/lib/tcl8.6/encoding/cp1252.enc
# rapids/lib/tcl8.6/encoding/cp857.enc
# rapids/lib/tcl8.6/encoding/macDingbats.enc
# rapids/lib/tcl8.6/encoding/tis-620.enc
# rapids/lib/tcl8.6/encoding/cp1257.enc
# rapids/lib/tcl8.6/encoding/cp865.enc
# rapids/lib/tcl8.6/encoding/cp1256.enc
# rapids/lib/tcl8.6/encoding/macTurkish.enc
# rapids/lib/tcl8.6/encoding/iso2022-kr.enc
# rapids/lib/tcl8.6/encoding/koi8-u.enc
# rapids/lib/tcl8.6/encoding/macCroatian.enc
# rapids/lib/tcl8.6/encoding/cp869.enc
# rapids/lib/tcl8.6/encoding/euc-cn.enc
# rapids/lib/tcl8.6/encoding/iso8859-15.enc
# rapids/lib/tcl8.6/encoding/cp860.enc
# rapids/lib/tcl8.6/encoding/cp1254.enc
# rapids/lib/tcl8.6/encoding/cp1255.enc
# rapids/lib/tcl8.6/encoding/iso8859-16.enc
# rapids/lib/tcl8.6/encoding/jis0208.enc
# rapids/lib/tcl8.6/encoding/cp950.enc
# rapids/lib/tcl8.6/encoding/cp1258.enc
# rapids/lib/tcl8.6/encoding/iso2022.enc
# rapids/lib/tcl8.6/encoding/macUkraine.enc
# rapids/lib/tcl8.6/encoding/cp1251.enc
# rapids/lib/tcl8.6/encoding/shiftjis.enc
# rapids/lib/tcl8.6/encoding/macCyrillic.enc
# rapids/lib/tcl8.6/encoding/cp852.enc
# rapids/lib/tcl8.6/encoding/koi8-r.enc
# rapids/lib/tcl8.6/encoding/iso2022-jp.enc
# rapids/lib/tcl8.6/encoding/macThai.enc
# rapids/lib/tcl8.6/encoding/euc-kr.enc
# rapids/lib/tcl8.6/encoding/gb2312.enc
# rapids/lib/tcl8.6/encoding/cp775.enc
# rapids/lib/tcl8.6/encoding/macRomania.enc
# rapids/lib/tcl8.6/encoding/jis0212.enc
# rapids/lib/tcl8.6/encoding/dingbats.enc
# rapids/lib/tcl8.6/encoding/gb2312-raw.enc
# rapids/lib/tcl8.6/encoding/cp855.enc
# rapids/lib/tcl8.6/encoding/macIceland.enc
# rapids/lib/tcl8.6/encoding/jis0201.enc
# rapids/lib/tcl8.6/encoding/cp737.enc
# rapids/lib/tcl8.6/encoding/cp850.enc
# rapids/lib/tcl8.6/encoding/big5.enc
# rapids/lib/tcl8.6/encoding/cp866.enc
# rapids/lib/tcl8.6/encoding/ebcdic.enc
# rapids/lib/tcl8.6/encoding/iso8859-5.enc
# rapids/lib/tcl8.6/encoding/iso8859-14.enc
# rapids/lib/tcl8.6/encoding/cp1250.enc
# rapids/lib/tcl8.6/encoding/cp864.enc
# rapids/lib/tcl8.6/encoding/cp874.enc
# rapids/lib/tcl8.6/encoding/iso8859-4.enc
# rapids/lib/tcl8.6/encoding/cp936.enc
# rapids/lib/tcl8.6/encoding/cp863.enc
# rapids/lib/tcl8.6/encoding/cp1253.enc
# rapids/lib/tcl8.6/encoding/macRoman.enc
# rapids/lib/tcl8.6/encoding/gb12345.enc
# rapids/lib/tcl8.6/encoding/cp861.enc
# rapids/lib/tcl8.6/encoding/iso8859-10.enc
# rapids/lib/tcl8.6/encoding/iso8859-13.enc
# rapids/lib/tcl8.6/encoding/iso8859-6.enc
# rapids/lib/tcl8.6/encoding/cp862.enc
# rapids/lib/tcl8.6/encoding/ksc5601.enc
# rapids/lib/tcl8.6/encoding/iso8859-2.enc
# rapids/lib/tcl8.6/encoding/macCentEuro.enc
# rapids/lib/tcl8.6/encoding/ascii.enc
# rapids/lib/tcl8.6/encoding/cp932.enc
# rapids/lib/tcl8.6/encoding/euc-jp.enc
# rapids/lib/tcl8.6/encoding/cp949.enc
# rapids/lib/tcl8.6/encoding/iso8859-9.enc
# rapids/lib/tcl8.6/encoding/iso8859-1.enc
# rapids/lib/tcl8.6/encoding/macJapan.enc
# rapids/lib/tcl8.6/history.tcl
# rapids/lib/tcl8.6/tm.tcl
# rapids/lib/tcl8.6/http1.0/
# rapids/lib/tcl8.6/http1.0/pkgIndex.tcl
# rapids/lib/tcl8.6/http1.0/http.tcl
# rapids/lib/tcl8.6/tclIndex
# rapids/lib/tcl8.6/safe.tcl
# rapids/lib/tcl8.6/auto.tcl
# rapids/lib/tcl8.6/init.tcl
# rapids/lib/tcl8.6/msgs/
# rapids/lib/tcl8.6/msgs/fo.msg
# rapids/lib/tcl8.6/msgs/de_at.msg
# rapids/lib/tcl8.6/msgs/ga.msg
# rapids/lib/tcl8.6/msgs/it_ch.msg
# rapids/lib/tcl8.6/msgs/en_sg.msg
# rapids/lib/tcl8.6/msgs/te_in.msg
# rapids/lib/tcl8.6/msgs/de.msg
# rapids/lib/tcl8.6/msgs/sl.msg
# rapids/lib/tcl8.6/msgs/fa_ir.msg
# rapids/lib/tcl8.6/msgs/fr_be.msg
# rapids/lib/tcl8.6/msgs/es_pr.msg
# rapids/lib/tcl8.6/msgs/en_ca.msg
# rapids/lib/tcl8.6/msgs/fr_ch.msg
# rapids/lib/tcl8.6/msgs/eo.msg
# rapids/lib/tcl8.6/msgs/es_pa.msg
# rapids/lib/tcl8.6/msgs/en_gb.msg
# rapids/lib/tcl8.6/msgs/sh.msg
# rapids/lib/tcl8.6/msgs/bn.msg
# rapids/lib/tcl8.6/msgs/hi_in.msg
# rapids/lib/tcl8.6/msgs/nl_be.msg
# rapids/lib/tcl8.6/msgs/es_ar.msg
# rapids/lib/tcl8.6/msgs/nl.msg
# rapids/lib/tcl8.6/msgs/es_do.msg
# rapids/lib/tcl8.6/msgs/af.msg
# rapids/lib/tcl8.6/msgs/ta_in.msg
# rapids/lib/tcl8.6/msgs/nn.msg
# rapids/lib/tcl8.6/msgs/en_in.msg
# rapids/lib/tcl8.6/msgs/kw_gb.msg
# rapids/lib/tcl8.6/msgs/gl.msg
# rapids/lib/tcl8.6/msgs/es_co.msg
# rapids/lib/tcl8.6/msgs/es_pe.msg
# rapids/lib/tcl8.6/msgs/ms.msg
# rapids/lib/tcl8.6/msgs/sr.msg
# rapids/lib/tcl8.6/msgs/es_hn.msg
# rapids/lib/tcl8.6/msgs/es_ni.msg
# rapids/lib/tcl8.6/msgs/kok_in.msg
# rapids/lib/tcl8.6/msgs/ca.msg
# rapids/lib/tcl8.6/msgs/en_ie.msg
# rapids/lib/tcl8.6/msgs/ko.msg
# rapids/lib/tcl8.6/msgs/zh.msg
# rapids/lib/tcl8.6/msgs/eu_es.msg
# rapids/lib/tcl8.6/msgs/es_ec.msg
# rapids/lib/tcl8.6/msgs/fr.msg
# rapids/lib/tcl8.6/msgs/es_uy.msg
# rapids/lib/tcl8.6/msgs/cs.msg
# rapids/lib/tcl8.6/msgs/en_za.msg
# rapids/lib/tcl8.6/msgs/sk.msg
# rapids/lib/tcl8.6/msgs/mt.msg
# rapids/lib/tcl8.6/msgs/mk.msg
# rapids/lib/tcl8.6/msgs/zh_sg.msg
# rapids/lib/tcl8.6/msgs/pt_br.msg
# rapids/lib/tcl8.6/msgs/kl_gl.msg
# rapids/lib/tcl8.6/msgs/fa.msg
# rapids/lib/tcl8.6/msgs/ru.msg
# rapids/lib/tcl8.6/msgs/de_be.msg
# rapids/lib/tcl8.6/msgs/lt.msg
# rapids/lib/tcl8.6/msgs/ro.msg
# rapids/lib/tcl8.6/msgs/mr.msg
# rapids/lib/tcl8.6/msgs/ar_sy.msg
# rapids/lib/tcl8.6/msgs/mr_in.msg
# rapids/lib/tcl8.6/msgs/et.msg
# rapids/lib/tcl8.6/msgs/te.msg
# rapids/lib/tcl8.6/msgs/hr.msg
# rapids/lib/tcl8.6/msgs/fo_fo.msg
# rapids/lib/tcl8.6/msgs/ms_my.msg
# rapids/lib/tcl8.6/msgs/sw.msg
# rapids/lib/tcl8.6/msgs/tr.msg
# rapids/lib/tcl8.6/msgs/pl.msg
# rapids/lib/tcl8.6/msgs/sv.msg
# rapids/lib/tcl8.6/msgs/es_gt.msg
# rapids/lib/tcl8.6/msgs/ar_jo.msg
# rapids/lib/tcl8.6/msgs/ko_kr.msg
# rapids/lib/tcl8.6/msgs/gv.msg
# rapids/lib/tcl8.6/msgs/zh_tw.msg
# rapids/lib/tcl8.6/msgs/en_be.msg
# rapids/lib/tcl8.6/msgs/gl_es.msg
# rapids/lib/tcl8.6/msgs/ar.msg
# rapids/lib/tcl8.6/msgs/ga_ie.msg
# rapids/lib/tcl8.6/msgs/th.msg
# rapids/lib/tcl8.6/msgs/ta.msg
# rapids/lib/tcl8.6/msgs/id.msg
# rapids/lib/tcl8.6/msgs/es.msg
# rapids/lib/tcl8.6/msgs/pt.msg
# rapids/lib/tcl8.6/msgs/fa_in.msg
# rapids/lib/tcl8.6/msgs/id_id.msg
# rapids/lib/tcl8.6/msgs/en_au.msg
# rapids/lib/tcl8.6/msgs/kl.msg
# rapids/lib/tcl8.6/msgs/fi.msg
# rapids/lib/tcl8.6/msgs/es_cl.msg
# rapids/lib/tcl8.6/msgs/it.msg
# rapids/lib/tcl8.6/msgs/ar_in.msg
# rapids/lib/tcl8.6/msgs/ja.msg
# rapids/lib/tcl8.6/msgs/bg.msg
# rapids/lib/tcl8.6/msgs/en_nz.msg
# rapids/lib/tcl8.6/msgs/lv.msg
# rapids/lib/tcl8.6/msgs/hi.msg
# rapids/lib/tcl8.6/msgs/nb.msg
# rapids/lib/tcl8.6/msgs/es_py.msg
# rapids/lib/tcl8.6/msgs/fr_ca.msg
# rapids/lib/tcl8.6/msgs/en_zw.msg
# rapids/lib/tcl8.6/msgs/kw.msg
# rapids/lib/tcl8.6/msgs/gv_gb.msg
# rapids/lib/tcl8.6/msgs/uk.msg
# rapids/lib/tcl8.6/msgs/is.msg
# rapids/lib/tcl8.6/msgs/es_cr.msg
# rapids/lib/tcl8.6/msgs/ru_ua.msg
# rapids/lib/tcl8.6/msgs/en_bw.msg
# rapids/lib/tcl8.6/msgs/be.msg
# rapids/lib/tcl8.6/msgs/zh_hk.msg
# rapids/lib/tcl8.6/msgs/da.msg
# rapids/lib/tcl8.6/msgs/es_sv.msg
# rapids/lib/tcl8.6/msgs/es_mx.msg
# rapids/lib/tcl8.6/msgs/bn_in.msg
# rapids/lib/tcl8.6/msgs/he.msg
# rapids/lib/tcl8.6/msgs/vi.msg
# rapids/lib/tcl8.6/msgs/zh_cn.msg
# rapids/lib/tcl8.6/msgs/sq.msg
# rapids/lib/tcl8.6/msgs/eu.msg
# rapids/lib/tcl8.6/msgs/af_za.msg
# rapids/lib/tcl8.6/msgs/en_hk.msg
# rapids/lib/tcl8.6/msgs/es_ve.msg
# rapids/lib/tcl8.6/msgs/en_ph.msg
# rapids/lib/tcl8.6/msgs/kok.msg
# rapids/lib/tcl8.6/msgs/el.msg
# rapids/lib/tcl8.6/msgs/es_bo.msg
# rapids/lib/tcl8.6/msgs/ar_lb.msg
# rapids/lib/tcl8.6/msgs/hu.msg
# rapids/lib/tcl8.6/tclAppInit.c
# rapids/lib/tcl8.6/word.tcl
# rapids/lib/tcl8.6/parray.tcl
# rapids/lib/tcl8.6/opt0.4/
# rapids/lib/tcl8.6/opt0.4/pkgIndex.tcl
# rapids/lib/tcl8.6/opt0.4/optparse.tcl
# rapids/lib/libboost_stacktrace_addr2line.so.1
# rapids/lib/libboost_atomic.a
# rapids/lib/libfreexl.so.1
# rapids/lib/utf8_and_johab.so
# rapids/lib/libboost_log.so.1
# rapids/lib/libatomic.so.1.2.0
# rapids/lib/libgssrpc.so.4
# rapids/lib/libboost_thread.so.1.70
# rapids/lib/libxcb-xinerama.so
# rapids/lib/libcairo.so
# rapids/lib/libcufftw.so
# rapids/lib/libcurl.a
# rapids/lib/libcurl.so.4
# rapids/lib/libkdb5.so.9.0
# rapids/lib/libpgfeutils.a
# rapids/lib/liburiparser.so
# rapids/lib/libboost_log_setup.so.1.70
# rapids/lib/libnppim.so
# rapids/lib/libnvgraph.so.10.1.243
# rapids/lib/libreadline.so.8.0
# rapids/lib/libubsan.so.1
# rapids/lib/libxml2.so.2.9.10
# rapids/lib/libxcb-randr.so.0
# rapids/lib/libcairo-script-interpreter.a
# rapids/lib/libparquet.so.15.0.0
# rapids/lib/libecpg_compat.so
# rapids/lib/libboost_graph.so.1.70
# rapids/lib/libboost_fiber.a
# rapids/lib/libquadmath.so
# rapids/lib/libarrow_python.so
# rapids/lib/libform.so
# rapids/lib/libboost_graph.so.1
# rapids/lib/libboost_context.so.1.70
# rapids/lib/libxcb-xfixes.so.0
# rapids/lib/libgeos-3.8.0.so
# rapids/lib/libarrow_flight.so.15
# rapids/lib/libnvrtc.so.10.1
# rapids/lib/libfreetype.a
# rapids/lib/libquadmath.so.0.0.0
# rapids/lib/libpq.so
# rapids/lib/libgrpc++_error_details.a
# rapids/lib/libcusparse.so.10
# rapids/lib/libdapclient.a
# rapids/lib/libdf.so.0.0.0
# rapids/lib/libnvjpeg.so.10
# rapids/lib/libverto.so.0.0
# rapids/lib/tclConfig.sh
# rapids/lib/libpcre.so.1
# rapids/lib/libdap.so.25.2.2
# rapids/lib/libnppif.so.10.2.0.243
# rapids/lib/libtinfo.so.6.1
# rapids/lib/passwordcheck.so
# rapids/lib/libzstd.so.1
# rapids/lib/libncursesw.a
# rapids/lib/libatomic.so.1
# rapids/lib/libhistory.a
# rapids/lib/libnppidei.so.10
# rapids/lib/libgrpc_unsecure.a
# rapids/lib/mod_spatialite.so.7
# rapids/lib/libhdf5_hl_cpp.so
# rapids/lib/libboost_container.so.1.70
# rapids/lib/xml2Conf.sh
# rapids/lib/openjpeg-2.3/
# rapids/lib/openjpeg-2.3/OpenJPEGConfig.cmake
# rapids/lib/openjpeg-2.3/OpenJPEGTargets.cmake
# rapids/lib/openjpeg-2.3/OpenJPEGTargets-noconfig.cmake
# rapids/lib/libhdf5_hl.so
# rapids/lib/libpcreposix.so.0
# rapids/lib/libicutest.so.64
# rapids/lib/libnpps.so
# rapids/lib/libssl.so.1.1
# rapids/lib/libhdf5hl_fortran.so.100
# rapids/lib/libgfortran.so.4
# rapids/lib/libgdal.a
# rapids/lib/libgobject-2.0.so.0
# rapids/lib/libxcb-glx.so.0
# rapids/lib/libxcb-shm.so
# rapids/lib/libreadline.so
# rapids/lib/libicudata.so
# rapids/lib/libsqlite3.a
# rapids/lib/libgssapi_krb5.so.2
# rapids/lib/libre2.so.0.0.0
# rapids/lib/libboost_system.a
# rapids/lib/insert_username.so
# rapids/lib/libxcb-screensaver.so.0
# rapids/lib/libboost_program_options.so.1.70
# rapids/lib/libnppicc.so.10
# rapids/lib/libkea.so
# rapids/lib/libasan.so.5.0.0
# rapids/lib/libhistory.so.8
# rapids/lib/libprotoc.a
# rapids/lib/libgdal.so.20
# rapids/lib/libsqlite3.so.0.8.6
# rapids/lib/libboost_math_tr1.so.1.70.0
# rapids/lib/utf8_and_euc_tw.so
# rapids/lib/libnppidei.so
# rapids/lib/libxcb-xv.so
# rapids/lib/tsm_system_time.so
# rapids/lib/libmfhdf.so
# rapids/lib/pgstattuple.so
# rapids/lib/libnvvm.so
# rapids/lib/libpoppler.so.78
# rapids/lib/file_fdw.so
# rapids/lib/libreadline.a
# rapids/lib/libnetcdf.so.15
# rapids/lib/pg_buffercache.so
# rapids/lib/libdapclient.so.6
# rapids/lib/libgflags_nothreads.so.2.2.2
# rapids/lib/libcfitsio.so
# rapids/lib/euc_cn_and_mic.so
# rapids/lib/libXext.so
# rapids/lib/libbrotlienc.so.1.0.7
# rapids/lib/utf8_and_ascii.so
# rapids/lib/utf8_and_win.so
# rapids/lib/libboost_unit_test_framework.a
# rapids/lib/libkadm5clnt_mit.so
# rapids/lib/libcairo-gobject.so
# rapids/lib/libmenuw.so.6
# rapids/lib/libk5crypto.so
# rapids/lib/libboost_contract.so.1
# rapids/lib/libdouble-conversion.so
# rapids/lib/libformw.so
# rapids/lib/libtinfo.a
# rapids/lib/libpng.so
# rapids/lib/libOptRemarks.so.8
# rapids/lib/euc_kr_and_mic.so
# rapids/lib/libboost_container.so
# rapids/lib/libpq.so.5.12
# rapids/lib/libiconv.a
# rapids/lib/libxcb.so
# rapids/lib/libxcb-dri3.so.0.0.0
# rapids/lib/libgrpc_csharp_ext.so
# rapids/lib/libtinfow.so.6.1
# rapids/lib/libhdf5_hl.so.100.1.2
# rapids/lib/libnppicc.so
# rapids/lib/libcares.so.2.3.0
# rapids/lib/liblz4.so
# rapids/lib/libxcb-xtest.so
# rapids/lib/libpython3.6m.so
# rapids/lib/libprotobuf.so.19.0.0
# rapids/lib/libmenu.so
# rapids/lib/libglog.so.0.4.0
# rapids/lib/libk5crypto.so.3
# rapids/lib/libblas.so
# rapids/lib/libxcb-xlib.so.0.0.0
# rapids/lib/pg_visibility.so
# rapids/lib/libpcre.a
# rapids/lib/libboost_math_tr1l.so
# rapids/lib/libformw.so.6.1
# rapids/lib/libprotobuf.so.19
# rapids/lib/libnvrtc-builtins.so.10.1
# rapids/lib/libprotobuf-lite.so.19.0.0
# rapids/lib/libparquet.so
# rapids/lib/libxcb-screensaver.so
# rapids/lib/libboost_wserialization.so.1
# rapids/lib/libnetcdf.a
# rapids/lib/libboost_contract.so
# rapids/lib/liblsan.so.0
# rapids/lib/tdbc1.1.1/
# rapids/lib/tdbc1.1.1/libtdbc1.1.1.so
# rapids/lib/tdbc1.1.1/pkgIndex.tcl
# rapids/lib/tdbc1.1.1/tdbc.tcl
# rapids/lib/tdbc1.1.1/tdbcConfig.sh
# rapids/lib/tdbc1.1.1/libtdbcstub1.1.1.a
# rapids/lib/libpgport_shlib.a
# rapids/lib/libthriftnb.so.0.12.0
# rapids/lib/libxcb-dpms.so.0.0.0
# rapids/lib/citext.so
# rapids/lib/libgettextpo.a
# rapids/lib/libboost_type_erasure.so.1.70.0
# rapids/lib/libxcb-xkb.so.1
# rapids/lib/libgssapi_krb5.so.2.2
# rapids/lib/preloadable_libintl.so
# rapids/lib/libboost_chrono.so.1.70
# rapids/lib/uuid-ossp.so
# rapids/lib/libcairo-script-interpreter.so
# rapids/lib/libcudart.so.10.1.243
# rapids/lib/libboost_filesystem.a
# rapids/lib/libevent_openssl-2.1.so.6
# rapids/lib/libxcb-xkb.so
# rapids/lib/libkmlconvenience.so.1.3.0
# rapids/lib/libstdc++.so
# rapids/lib/libcufft.so.10
# rapids/lib/libncurses.so.6.1
# rapids/lib/liblz4.so.1.8.3
# rapids/lib/libX11.so.6
# rapids/lib/libxcb-xf86dri.so.0.0.0
# rapids/lib/libboost_math_c99f.so
# rapids/lib/libglib-2.0.so
# rapids/lib/libboost_timer.so.1.70
# rapids/lib/libitm.so.1.0.0
# rapids/lib/libpoppler-glib.so
# rapids/lib/libxcb-damage.so
# rapids/lib/libboost_math_tr1l.so.1.70
# rapids/lib/pgrowlocks.so
# rapids/lib/libboost_math_tr1l.so.1
# rapids/lib/libboost_stacktrace_basic.a
# rapids/lib/libthriftnb.so
# rapids/lib/libyaml-0.so.2
# rapids/lib/libgflags_nothreads.a
# rapids/lib/libnvjpeg.so
# rapids/lib/libboost_atomic.so.1.70
# rapids/lib/libtkstub8.6.a
# rapids/lib/libjson-c.a
# rapids/lib/libicutu.so.64.2
# rapids/lib/libboost_date_time.so.1
# rapids/lib/libbrotlienc-static.a
# rapids/lib/libpanelw.a
# rapids/lib/libboost_contract.so.1.70
# rapids/lib/libgif.so.7.1.0
# rapids/lib/libboost_prg_exec_monitor.so.1.70.0
# rapids/lib/libthriftnb.a
# rapids/lib/libgandiva.so.15
# rapids/lib/libcom_err.so.3.0
# rapids/lib/libicutest.so.64.2
# rapids/lib/libcusolver.so.10
# rapids/lib/cmake/
# rapids/lib/cmake/boost_filesystem-1.70.0/
# rapids/lib/cmake/boost_filesystem-1.70.0/boost_filesystem-config-version.cmake
# rapids/lib/cmake/boost_filesystem-1.70.0/libboost_filesystem-variant-shared.cmake
# rapids/lib/cmake/boost_filesystem-1.70.0/boost_filesystem-config.cmake
# rapids/lib/cmake/boost_filesystem-1.70.0/libboost_filesystem-variant-static.cmake
# rapids/lib/cmake/boost_test_exec_monitor-1.70.0/
# rapids/lib/cmake/boost_test_exec_monitor-1.70.0/boost_test_exec_monitor-config.cmake
# rapids/lib/cmake/boost_test_exec_monitor-1.70.0/libboost_test_exec_monitor-variant-static.cmake
# rapids/lib/cmake/boost_test_exec_monitor-1.70.0/boost_test_exec_monitor-config-version.cmake
# rapids/lib/cmake/boost_test_exec_monitor-1.70.0/libboost_test_exec_monitor-variant-shared.cmake
# rapids/lib/cmake/boost_fiber_numa-1.70.0/
# rapids/lib/cmake/boost_fiber_numa-1.70.0/boost_fiber_numa-config.cmake
# rapids/lib/cmake/boost_fiber_numa-1.70.0/libboost_fiber_numa-variant-shared.cmake
# rapids/lib/cmake/boost_fiber_numa-1.70.0/libboost_fiber_numa-variant-static.cmake
# rapids/lib/cmake/boost_fiber_numa-1.70.0/boost_fiber_numa-config-version.cmake
# rapids/lib/cmake/boost_log-1.70.0/
# rapids/lib/cmake/boost_log-1.70.0/boost_log-config-version.cmake
# rapids/lib/cmake/boost_log-1.70.0/boost_log-config.cmake
# rapids/lib/cmake/boost_log-1.70.0/libboost_log-variant-static.cmake
# rapids/lib/cmake/boost_log-1.70.0/libboost_log-variant-shared.cmake
# rapids/lib/cmake/boost_wave-1.70.0/
# rapids/lib/cmake/boost_wave-1.70.0/boost_wave-config.cmake
# rapids/lib/cmake/boost_wave-1.70.0/boost_wave-config-version.cmake
# rapids/lib/cmake/boost_wave-1.70.0/libboost_wave-variant-shared.cmake
# rapids/lib/cmake/boost_wave-1.70.0/libboost_wave-variant-static.cmake
# rapids/lib/cmake/boost_stacktrace_basic-1.70.0/
# rapids/lib/cmake/boost_stacktrace_basic-1.70.0/boost_stacktrace_basic-config-version.cmake
# rapids/lib/cmake/boost_stacktrace_basic-1.70.0/boost_stacktrace_basic-config.cmake
# rapids/lib/cmake/boost_stacktrace_basic-1.70.0/libboost_stacktrace_basic-variant-static.cmake
# rapids/lib/cmake/boost_stacktrace_basic-1.70.0/libboost_stacktrace_basic-variant-shared.cmake
# rapids/lib/cmake/boost_log_setup-1.70.0/
# rapids/lib/cmake/boost_log_setup-1.70.0/boost_log_setup-config-version.cmake
# rapids/lib/cmake/boost_log_setup-1.70.0/libboost_log_setup-variant-shared.cmake
# rapids/lib/cmake/boost_log_setup-1.70.0/boost_log_setup-config.cmake
# rapids/lib/cmake/boost_log_setup-1.70.0/libboost_log_setup-variant-static.cmake
# rapids/lib/cmake/libkml/
# rapids/lib/cmake/libkml/LibKMLConfig.cmake
# rapids/lib/cmake/libkml/LibKMLTargets.cmake
# rapids/lib/cmake/libkml/LibKMLTargets-release.cmake
# rapids/lib/cmake/libkml/LibKMLConfigVersion.cmake
# rapids/lib/cmake/Boost-1.70.0/
# rapids/lib/cmake/Boost-1.70.0/BoostConfigVersion.cmake
# rapids/lib/cmake/Boost-1.70.0/BoostConfig.cmake
# rapids/lib/cmake/boost_regex-1.70.0/
# rapids/lib/cmake/boost_regex-1.70.0/libboost_regex-variant-shared.cmake
# rapids/lib/cmake/boost_regex-1.70.0/boost_regex-config.cmake
# rapids/lib/cmake/boost_regex-1.70.0/libboost_regex-variant-static.cmake
# rapids/lib/cmake/boost_regex-1.70.0/boost_regex-config-version.cmake
# rapids/lib/cmake/c-ares/
# rapids/lib/cmake/c-ares/c-ares-config.cmake
# rapids/lib/cmake/c-ares/c-ares-targets.cmake
# rapids/lib/cmake/c-ares/c-ares-targets-release.cmake
# rapids/lib/cmake/boost_coroutine-1.70.0/
# rapids/lib/cmake/boost_coroutine-1.70.0/boost_coroutine-config-version.cmake
# rapids/lib/cmake/boost_coroutine-1.70.0/boost_coroutine-config.cmake
# rapids/lib/cmake/boost_coroutine-1.70.0/libboost_coroutine-variant-static.cmake
# rapids/lib/cmake/boost_coroutine-1.70.0/libboost_coroutine-variant-shared.cmake
# rapids/lib/cmake/boost_math-1.70.0/
# rapids/lib/cmake/boost_math-1.70.0/boost_math-config-version.cmake
# rapids/lib/cmake/boost_math-1.70.0/boost_math-config.cmake
# rapids/lib/cmake/boost_system-1.70.0/
# rapids/lib/cmake/boost_system-1.70.0/libboost_system-variant-static.cmake
# rapids/lib/cmake/boost_system-1.70.0/boost_system-config-version.cmake
# rapids/lib/cmake/boost_system-1.70.0/boost_system-config.cmake
# rapids/lib/cmake/boost_system-1.70.0/libboost_system-variant-shared.cmake
# rapids/lib/cmake/libssh2/
# rapids/lib/cmake/libssh2/Libssh2Config.cmake
# rapids/lib/cmake/libssh2/Libssh2ConfigVersion.cmake
# rapids/lib/cmake/libssh2/Libssh2Config-noconfig.cmake
# rapids/lib/cmake/boost_math_c99-1.70.0/
# rapids/lib/cmake/boost_math_c99-1.70.0/boost_math_c99-config-version.cmake
# rapids/lib/cmake/boost_math_c99-1.70.0/libboost_math_c99-variant-shared.cmake
# rapids/lib/cmake/boost_math_c99-1.70.0/boost_math_c99-config.cmake
# rapids/lib/cmake/boost_math_c99-1.70.0/libboost_math_c99-variant-static.cmake
# rapids/lib/cmake/boost_wserialization-1.70.0/
# rapids/lib/cmake/boost_wserialization-1.70.0/libboost_wserialization-variant-static.cmake
# rapids/lib/cmake/boost_wserialization-1.70.0/boost_wserialization-config.cmake
# rapids/lib/cmake/boost_wserialization-1.70.0/boost_wserialization-config-version.cmake
# rapids/lib/cmake/boost_wserialization-1.70.0/libboost_wserialization-variant-shared.cmake
# rapids/lib/cmake/boost_math_tr1l-1.70.0/
# rapids/lib/cmake/boost_math_tr1l-1.70.0/boost_math_tr1l-config-version.cmake
# rapids/lib/cmake/boost_math_tr1l-1.70.0/libboost_math_tr1l-variant-shared.cmake
# rapids/lib/cmake/boost_math_tr1l-1.70.0/boost_math_tr1l-config.cmake
# rapids/lib/cmake/boost_math_tr1l-1.70.0/libboost_math_tr1l-variant-static.cmake
# rapids/lib/cmake/Snappy/
# rapids/lib/cmake/Snappy/SnappyConfig.cmake
# rapids/lib/cmake/Snappy/SnappyTargets-noconfig.cmake
# rapids/lib/cmake/Snappy/SnappyConfigVersion.cmake
# rapids/lib/cmake/Snappy/SnappyTargets.cmake
# rapids/lib/cmake/boost_chrono-1.70.0/
# rapids/lib/cmake/boost_chrono-1.70.0/libboost_chrono-variant-static.cmake
# rapids/lib/cmake/boost_chrono-1.70.0/boost_chrono-config-version.cmake
# rapids/lib/cmake/boost_chrono-1.70.0/boost_chrono-config.cmake
# rapids/lib/cmake/boost_chrono-1.70.0/libboost_chrono-variant-shared.cmake
# rapids/lib/cmake/boost_math_c99l-1.70.0/
# rapids/lib/cmake/boost_math_c99l-1.70.0/libboost_math_c99l-variant-shared.cmake
# rapids/lib/cmake/boost_math_c99l-1.70.0/libboost_math_c99l-variant-static.cmake
# rapids/lib/cmake/boost_math_c99l-1.70.0/boost_math_c99l-config-version.cmake
# rapids/lib/cmake/boost_math_c99l-1.70.0/boost_math_c99l-config.cmake
# rapids/lib/cmake/boost_stacktrace_backtrace-1.70.0/
# rapids/lib/cmake/boost_stacktrace_backtrace-1.70.0/libboost_stacktrace_backtrace-variant-shared.cmake
# rapids/lib/cmake/boost_stacktrace_backtrace-1.70.0/libboost_stacktrace_backtrace-variant-static.cmake
# rapids/lib/cmake/boost_stacktrace_backtrace-1.70.0/boost_stacktrace_backtrace-config-version.cmake
# rapids/lib/cmake/boost_stacktrace_backtrace-1.70.0/boost_stacktrace_backtrace-config.cmake
# rapids/lib/cmake/boost_headers-1.70.0/
# rapids/lib/cmake/boost_headers-1.70.0/boost_headers-config-version.cmake
# rapids/lib/cmake/boost_headers-1.70.0/boost_headers-config.cmake
# rapids/lib/cmake/BoostDetectToolset-1.70.0.cmake
# rapids/lib/cmake/boost_math_tr1f-1.70.0/
# rapids/lib/cmake/boost_math_tr1f-1.70.0/libboost_math_tr1f-variant-static.cmake
# rapids/lib/cmake/boost_math_tr1f-1.70.0/boost_math_tr1f-config-version.cmake
# rapids/lib/cmake/boost_math_tr1f-1.70.0/boost_math_tr1f-config.cmake
# rapids/lib/cmake/boost_math_tr1f-1.70.0/libboost_math_tr1f-variant-shared.cmake
# rapids/lib/cmake/boost_math_c99f-1.70.0/
# rapids/lib/cmake/boost_math_c99f-1.70.0/boost_math_c99f-config.cmake
# rapids/lib/cmake/boost_math_c99f-1.70.0/boost_math_c99f-config-version.cmake
# rapids/lib/cmake/boost_math_c99f-1.70.0/libboost_math_c99f-variant-shared.cmake
# rapids/lib/cmake/boost_math_c99f-1.70.0/libboost_math_c99f-variant-static.cmake
# rapids/lib/cmake/libxml2/
# rapids/lib/cmake/libxml2/libxml2-config.cmake
# rapids/lib/cmake/boost_stacktrace_windbg-1.70.0/
# rapids/lib/cmake/boost_stacktrace_windbg-1.70.0/libboost_stacktrace_windbg-variant-static.cmake
# rapids/lib/cmake/boost_stacktrace_windbg-1.70.0/libboost_stacktrace_windbg-variant-shared.cmake
# rapids/lib/cmake/boost_stacktrace_windbg-1.70.0/boost_stacktrace_windbg-config-version.cmake
# rapids/lib/cmake/boost_stacktrace_windbg-1.70.0/boost_stacktrace_windbg-config.cmake
# rapids/lib/cmake/gflags/
# rapids/lib/cmake/gflags/gflags-config.cmake
# rapids/lib/cmake/gflags/gflags-targets.cmake
# rapids/lib/cmake/gflags/gflags-nonamespace-targets.cmake
# rapids/lib/cmake/gflags/gflags-targets-noconfig.cmake
# rapids/lib/cmake/gflags/gflags-nonamespace-targets-noconfig.cmake
# rapids/lib/cmake/gflags/gflags-config-version.cmake
# rapids/lib/cmake/arrow/
# rapids/lib/cmake/arrow/arrowConfigVersion.cmake
# rapids/lib/cmake/arrow/arrowOptions.cmake
# rapids/lib/cmake/arrow/arrowTargets-release.cmake
# rapids/lib/cmake/arrow/arrowTargets.cmake
# rapids/lib/cmake/arrow/arrowConfig.cmake
# rapids/lib/cmake/boost_graph-1.70.0/
# rapids/lib/cmake/boost_graph-1.70.0/libboost_graph-variant-shared.cmake
# rapids/lib/cmake/boost_graph-1.70.0/libboost_graph-variant-static.cmake
# rapids/lib/cmake/boost_graph-1.70.0/boost_graph-config-version.cmake
# rapids/lib/cmake/boost_graph-1.70.0/boost_graph-config.cmake
# rapids/lib/cmake/boost_contract-1.70.0/
# rapids/lib/cmake/boost_contract-1.70.0/libboost_contract-variant-shared.cmake
# rapids/lib/cmake/boost_contract-1.70.0/libboost_contract-variant-static.cmake
# rapids/lib/cmake/boost_contract-1.70.0/boost_contract-config.cmake
# rapids/lib/cmake/boost_contract-1.70.0/boost_contract-config-version.cmake
# rapids/lib/cmake/boost_mpi-1.70.0/
# rapids/lib/cmake/boost_mpi-1.70.0/boost_mpi-config.cmake
# rapids/lib/cmake/boost_mpi-1.70.0/libboost_mpi-variant-shared.cmake
# rapids/lib/cmake/boost_mpi-1.70.0/libboost_mpi-variant-static.cmake
# rapids/lib/cmake/boost_mpi-1.70.0/boost_mpi-config-version.cmake
# rapids/lib/cmake/boost_thread-1.70.0/
# rapids/lib/cmake/boost_thread-1.70.0/boost_thread-config-version.cmake
# rapids/lib/cmake/boost_thread-1.70.0/libboost_thread-variant-shared.cmake
# rapids/lib/cmake/boost_thread-1.70.0/boost_thread-config.cmake
# rapids/lib/cmake/boost_thread-1.70.0/libboost_thread-variant-static.cmake
# rapids/lib/cmake/boost_graph_parallel-1.70.0/
# rapids/lib/cmake/boost_graph_parallel-1.70.0/boost_graph_parallel-config-version.cmake
# rapids/lib/cmake/boost_graph_parallel-1.70.0/libboost_graph_parallel-variant-shared.cmake
# rapids/lib/cmake/boost_graph_parallel-1.70.0/libboost_graph_parallel-variant-static.cmake
# rapids/lib/cmake/boost_graph_parallel-1.70.0/boost_graph_parallel-config.cmake
# rapids/lib/cmake/boost_iostreams-1.70.0/
# rapids/lib/cmake/boost_iostreams-1.70.0/boost_iostreams-config.cmake
# rapids/lib/cmake/boost_iostreams-1.70.0/libboost_iostreams-variant-static.cmake
# rapids/lib/cmake/boost_iostreams-1.70.0/boost_iostreams-config-version.cmake
# rapids/lib/cmake/boost_iostreams-1.70.0/libboost_iostreams-variant-shared.cmake
# rapids/lib/cmake/boost_locale-1.70.0/
# rapids/lib/cmake/boost_locale-1.70.0/boost_locale-config-version.cmake
# rapids/lib/cmake/boost_locale-1.70.0/libboost_locale-variant-static.cmake
# rapids/lib/cmake/boost_locale-1.70.0/libboost_locale-variant-shared.cmake
# rapids/lib/cmake/boost_locale-1.70.0/boost_locale-config.cmake
# rapids/lib/cmake/boost_exception-1.70.0/
# rapids/lib/cmake/boost_exception-1.70.0/boost_exception-config-version.cmake
# rapids/lib/cmake/boost_exception-1.70.0/boost_exception-config.cmake
# rapids/lib/cmake/boost_atomic-1.70.0/
# rapids/lib/cmake/boost_atomic-1.70.0/libboost_atomic-variant-shared.cmake
# rapids/lib/cmake/boost_atomic-1.70.0/libboost_atomic-variant-static.cmake
# rapids/lib/cmake/boost_atomic-1.70.0/boost_atomic-config-version.cmake
# rapids/lib/cmake/boost_atomic-1.70.0/boost_atomic-config.cmake
# rapids/lib/cmake/boost_context-1.70.0/
# rapids/lib/cmake/boost_context-1.70.0/libboost_context-variant-static.cmake
# rapids/lib/cmake/boost_context-1.70.0/boost_context-config-version.cmake
# rapids/lib/cmake/boost_context-1.70.0/boost_context-config.cmake
# rapids/lib/cmake/boost_context-1.70.0/libboost_context-variant-shared.cmake
# rapids/lib/cmake/boost_type_erasure-1.70.0/
# rapids/lib/cmake/boost_type_erasure-1.70.0/libboost_type_erasure-variant-static.cmake
# rapids/lib/cmake/boost_type_erasure-1.70.0/boost_type_erasure-config.cmake
# rapids/lib/cmake/boost_type_erasure-1.70.0/libboost_type_erasure-variant-shared.cmake
# rapids/lib/cmake/boost_type_erasure-1.70.0/boost_type_erasure-config-version.cmake
# rapids/lib/cmake/boost_serialization-1.70.0/
# rapids/lib/cmake/boost_serialization-1.70.0/libboost_serialization-variant-static.cmake
# rapids/lib/cmake/boost_serialization-1.70.0/boost_serialization-config.cmake
# rapids/lib/cmake/boost_serialization-1.70.0/libboost_serialization-variant-shared.cmake
# rapids/lib/cmake/boost_serialization-1.70.0/boost_serialization-config-version.cmake
# rapids/lib/cmake/boost_date_time-1.70.0/
# rapids/lib/cmake/boost_date_time-1.70.0/libboost_date_time-variant-static.cmake
# rapids/lib/cmake/boost_date_time-1.70.0/libboost_date_time-variant-shared.cmake
# rapids/lib/cmake/boost_date_time-1.70.0/boost_date_time-config.cmake
# rapids/lib/cmake/boost_date_time-1.70.0/boost_date_time-config-version.cmake
# rapids/lib/cmake/boost_stacktrace_addr2line-1.70.0/
# rapids/lib/cmake/boost_stacktrace_addr2line-1.70.0/boost_stacktrace_addr2line-config.cmake
# ...
# rapids/share/zoneinfo/Antarctica/Davis
# rapids/share/zoneinfo/Antarctica/Casey
# rapids/share/zoneinfo/Antarctica/DumontDUrville
# rapids/share/zoneinfo/Antarctica/Palmer
# rapids/share/zoneinfo/Antarctica/McMurdo
# rapids/share/zoneinfo/Antarctica/Mawson
# rapids/share/zoneinfo/Antarctica/Troll
# rapids/share/zoneinfo/WET
# rapids/share/zoneinfo/MST
# rapids/share/zoneinfo/leapseconds
# rapids/share/zoneinfo/GB-Eire
# rapids/share/zoneinfo/Iceland
# rapids/share/zoneinfo/Hongkong
# rapids/share/zoneinfo/Cuba
# rapids/share/zoneinfo/GMT0
# rapids/share/zoneinfo/posixrules
# rapids/share/zoneinfo/GMT+0
# rapids/share/zoneinfo/Atlantic/
# rapids/share/zoneinfo/Atlantic/Canary
# rapids/share/zoneinfo/Atlantic/Faeroe
# rapids/share/zoneinfo/Atlantic/Faroe
# rapids/share/zoneinfo/Atlantic/St_Helena
# rapids/share/zoneinfo/Atlantic/Reykjavik
# rapids/share/zoneinfo/Atlantic/Stanley
# rapids/share/zoneinfo/Atlantic/Jan_Mayen
# rapids/share/zoneinfo/Atlantic/Bermuda
# rapids/share/zoneinfo/Atlantic/Cape_Verde
# rapids/share/zoneinfo/Atlantic/Azores
# rapids/share/zoneinfo/Atlantic/Madeira
# rapids/share/zoneinfo/Atlantic/South_Georgia
# rapids/share/zoneinfo/NZ-CHAT
# rapids/share/zoneinfo/Canada/
# rapids/share/zoneinfo/Canada/Central
# rapids/share/zoneinfo/Canada/Newfoundland
# rapids/share/zoneinfo/Canada/Yukon
# rapids/share/zoneinfo/Canada/Mountain
# rapids/share/zoneinfo/Canada/Saskatchewan
# rapids/share/zoneinfo/Canada/Atlantic
# rapids/share/zoneinfo/Canada/Pacific
# rapids/share/zoneinfo/Canada/Eastern
# rapids/share/zoneinfo/Factory
# rapids/share/zoneinfo/Europe/
# rapids/share/zoneinfo/Europe/Berlin
# rapids/share/zoneinfo/Europe/Sarajevo
# rapids/share/zoneinfo/Europe/Volgograd
# rapids/share/zoneinfo/Europe/Mariehamn
# rapids/share/zoneinfo/Europe/Astrakhan
# rapids/share/zoneinfo/Europe/Malta
# rapids/share/zoneinfo/Europe/Stockholm
# rapids/share/zoneinfo/Europe/Riga
# rapids/share/zoneinfo/Europe/Podgorica
# rapids/share/zoneinfo/Europe/Busingen
# rapids/share/zoneinfo/Europe/Gibraltar
# rapids/share/zoneinfo/Europe/Tirane
# rapids/share/zoneinfo/Europe/Prague
# rapids/share/zoneinfo/Europe/Isle_of_Man
# rapids/share/zoneinfo/Europe/Tallinn
# rapids/share/zoneinfo/Europe/Zagreb
# rapids/share/zoneinfo/Europe/Sofia
# rapids/share/zoneinfo/Europe/Zurich
# rapids/share/zoneinfo/Europe/Kaliningrad
# rapids/share/zoneinfo/Europe/Simferopol
# rapids/share/zoneinfo/Europe/Moscow
# rapids/share/zoneinfo/Europe/Kiev
# rapids/share/zoneinfo/Europe/Monaco
# rapids/share/zoneinfo/Europe/Ulyanovsk
# rapids/share/zoneinfo/Europe/Belfast
# rapids/share/zoneinfo/Europe/Vatican
# rapids/share/zoneinfo/Europe/Rome
# rapids/share/zoneinfo/Europe/Oslo
# rapids/share/zoneinfo/Europe/Vilnius
# rapids/share/zoneinfo/Europe/Brussels
# rapids/share/zoneinfo/Europe/Copenhagen
# rapids/share/zoneinfo/Europe/Andorra
# rapids/share/zoneinfo/Europe/Warsaw
# rapids/share/zoneinfo/Europe/Jersey
# rapids/share/zoneinfo/Europe/Kirov
# rapids/share/zoneinfo/Europe/Minsk
# rapids/share/zoneinfo/Europe/Saratov
# rapids/share/zoneinfo/Europe/Helsinki
# rapids/share/zoneinfo/Europe/Istanbul
# rapids/share/zoneinfo/Europe/Amsterdam
# rapids/share/zoneinfo/Europe/Paris
# rapids/share/zoneinfo/Europe/Chisinau
# rapids/share/zoneinfo/Europe/Nicosia
# rapids/share/zoneinfo/Europe/Guernsey
# rapids/share/zoneinfo/Europe/Skopje
# rapids/share/zoneinfo/Europe/Bucharest
# rapids/share/zoneinfo/Europe/Athens
# rapids/share/zoneinfo/Europe/London
# rapids/share/zoneinfo/Europe/Zaporozhye
# rapids/share/zoneinfo/Europe/Tiraspol
# rapids/share/zoneinfo/Europe/Ljubljana
# rapids/share/zoneinfo/Europe/Vienna
# rapids/share/zoneinfo/Europe/San_Marino
# rapids/share/zoneinfo/Europe/Dublin
# rapids/share/zoneinfo/Europe/Lisbon
# rapids/share/zoneinfo/Europe/Luxembourg
# rapids/share/zoneinfo/Europe/Vaduz
# rapids/share/zoneinfo/Europe/Belgrade
# rapids/share/zoneinfo/Europe/Uzhgorod
# rapids/share/zoneinfo/Europe/Samara
# rapids/share/zoneinfo/Europe/Bratislava
# rapids/share/zoneinfo/Europe/Madrid
# rapids/share/zoneinfo/Europe/Budapest
# rapids/share/zoneinfo/GMT-0
# rapids/share/zoneinfo/ROK
# rapids/share/zoneinfo/Iran
# rapids/share/zoneinfo/Singapore
# rapids/share/zoneinfo/CET
# rapids/share/zoneinfo/ROC
# rapids/share/zoneinfo/America/
# rapids/share/zoneinfo/America/Kentucky/
# rapids/share/zoneinfo/America/Kentucky/Monticello
# rapids/share/zoneinfo/America/Kentucky/Louisville
# rapids/share/zoneinfo/America/Manaus
# rapids/share/zoneinfo/America/Anguilla
# rapids/share/zoneinfo/America/Nipigon
# rapids/share/zoneinfo/America/Moncton
# rapids/share/zoneinfo/America/Winnipeg
# rapids/share/zoneinfo/America/Cayenne
# rapids/share/zoneinfo/America/Paramaribo
# rapids/share/zoneinfo/America/Los_Angeles
# rapids/share/zoneinfo/America/Indianapolis
# rapids/share/zoneinfo/America/Guyana
# rapids/share/zoneinfo/America/Santiago
# rapids/share/zoneinfo/America/Puerto_Rico
# rapids/share/zoneinfo/America/Danmarkshavn
# rapids/share/zoneinfo/America/Whitehorse
# rapids/share/zoneinfo/America/Anchorage
# rapids/share/zoneinfo/America/Guayaquil
# rapids/share/zoneinfo/America/Grand_Turk
# rapids/share/zoneinfo/America/New_York
# rapids/share/zoneinfo/America/Atikokan
# rapids/share/zoneinfo/America/Havana
# rapids/share/zoneinfo/America/Yakutat
# rapids/share/zoneinfo/America/St_Vincent
# rapids/share/zoneinfo/America/Miquelon
# rapids/share/zoneinfo/America/Yellowknife
# rapids/share/zoneinfo/America/Managua
# rapids/share/zoneinfo/America/Asuncion
# rapids/share/zoneinfo/America/Thunder_Bay
# rapids/share/zoneinfo/America/Denver
# rapids/share/zoneinfo/America/Martinique
# rapids/share/zoneinfo/America/Iqaluit
# rapids/share/zoneinfo/America/Antigua
# rapids/share/zoneinfo/America/Lima
# rapids/share/zoneinfo/America/Mazatlan
# rapids/share/zoneinfo/America/Guadeloupe
# rapids/share/zoneinfo/America/Swift_Current
# rapids/share/zoneinfo/America/Porto_Acre
# rapids/share/zoneinfo/America/Barbados
# rapids/share/zoneinfo/America/Toronto
# rapids/share/zoneinfo/America/Eirunepe
# rapids/share/zoneinfo/America/Ojinaga
# rapids/share/zoneinfo/America/Juneau
# rapids/share/zoneinfo/America/Araguaina
# rapids/share/zoneinfo/America/Cancun
# rapids/share/zoneinfo/America/Dominica
# rapids/share/zoneinfo/America/Thule
# rapids/share/zoneinfo/America/Guatemala
# rapids/share/zoneinfo/America/Noronha
# rapids/share/zoneinfo/America/Belize
# rapids/share/zoneinfo/America/Scoresbysund
# rapids/share/zoneinfo/America/Glace_Bay
# rapids/share/zoneinfo/America/Hermosillo
# rapids/share/zoneinfo/America/Boa_Vista
# rapids/share/zoneinfo/America/Montevideo
# rapids/share/zoneinfo/America/Godthab
# rapids/share/zoneinfo/America/Grenada
# rapids/share/zoneinfo/America/Bogota
# rapids/share/zoneinfo/America/Curacao
# rapids/share/zoneinfo/America/St_Johns
# rapids/share/zoneinfo/America/Jujuy
# rapids/share/zoneinfo/America/Cuiaba
# rapids/share/zoneinfo/America/Pangnirtung
# rapids/share/zoneinfo/America/Mexico_City
# rapids/share/zoneinfo/America/St_Lucia
# rapids/share/zoneinfo/America/Lower_Princes
# rapids/share/zoneinfo/America/Fortaleza
# rapids/share/zoneinfo/America/Kralendijk
# rapids/share/zoneinfo/America/Regina
# rapids/share/zoneinfo/America/Campo_Grande
# rapids/share/zoneinfo/America/Phoenix
# rapids/share/zoneinfo/America/Boise
# rapids/share/zoneinfo/America/Louisville
# rapids/share/zoneinfo/America/Dawson
# rapids/share/zoneinfo/America/Cambridge_Bay
# rapids/share/zoneinfo/America/Port_of_Spain
# rapids/share/zoneinfo/America/Blanc-Sablon
# rapids/share/zoneinfo/America/Rio_Branco
# rapids/share/zoneinfo/America/Fort_Wayne
# rapids/share/zoneinfo/America/Rainy_River
# rapids/share/zoneinfo/America/La_Paz
# rapids/share/zoneinfo/America/Rosario
# rapids/share/zoneinfo/America/Adak
# rapids/share/zoneinfo/America/Catamarca
# rapids/share/zoneinfo/America/Virgin
# rapids/share/zoneinfo/America/Marigot
# rapids/share/zoneinfo/America/Merida
# rapids/share/zoneinfo/America/Santarem
# rapids/share/zoneinfo/America/Knox_IN
# rapids/share/zoneinfo/America/Chicago
# rapids/share/zoneinfo/America/Coral_Harbour
# rapids/share/zoneinfo/America/Maceio
# rapids/share/zoneinfo/America/Santo_Domingo
# rapids/share/zoneinfo/America/Rankin_Inlet
# rapids/share/zoneinfo/America/Creston
# rapids/share/zoneinfo/America/Porto_Velho
# rapids/share/zoneinfo/America/Tortola
# rapids/share/zoneinfo/America/Inuvik
# rapids/share/zoneinfo/America/Caracas
# rapids/share/zoneinfo/America/Resolute
# rapids/share/zoneinfo/America/Tijuana
# rapids/share/zoneinfo/America/Santa_Isabel
# rapids/share/zoneinfo/America/Belem
# rapids/share/zoneinfo/America/North_Dakota/
# rapids/share/zoneinfo/America/North_Dakota/Center
# rapids/share/zoneinfo/America/North_Dakota/Beulah
# rapids/share/zoneinfo/America/North_Dakota/New_Salem
# rapids/share/zoneinfo/America/Mendoza
# rapids/share/zoneinfo/America/Chihuahua
# rapids/share/zoneinfo/America/Tegucigalpa
# rapids/share/zoneinfo/America/Cayman
# rapids/share/zoneinfo/America/Fort_Nelson
# rapids/share/zoneinfo/America/St_Kitts
# rapids/share/zoneinfo/America/Bahia_Banderas
# rapids/share/zoneinfo/America/St_Barthelemy
# rapids/share/zoneinfo/America/Metlakatla
# rapids/share/zoneinfo/America/Cordoba
# rapids/share/zoneinfo/America/Recife
# rapids/share/zoneinfo/America/Aruba
# rapids/share/zoneinfo/America/Montserrat
# rapids/share/zoneinfo/America/Port-au-Prince
# rapids/share/zoneinfo/America/El_Salvador
# rapids/share/zoneinfo/America/Argentina/
# rapids/share/zoneinfo/America/Argentina/San_Luis
# rapids/share/zoneinfo/America/Argentina/Jujuy
# rapids/share/zoneinfo/America/Argentina/Rio_Gallegos
# rapids/share/zoneinfo/America/Argentina/Catamarca
# rapids/share/zoneinfo/America/Argentina/Tucuman
# rapids/share/zoneinfo/America/Argentina/Mendoza
# rapids/share/zoneinfo/America/Argentina/Ushuaia
# rapids/share/zoneinfo/America/Argentina/Salta
# rapids/share/zoneinfo/America/Argentina/ComodRivadavia
# rapids/share/zoneinfo/America/Argentina/Cordoba
# rapids/share/zoneinfo/America/Argentina/Buenos_Aires
# rapids/share/zoneinfo/America/Argentina/La_Rioja
# rapids/share/zoneinfo/America/Argentina/San_Juan
# rapids/share/zoneinfo/America/Atka
# rapids/share/zoneinfo/America/Menominee
# rapids/share/zoneinfo/America/Buenos_Aires
# rapids/share/zoneinfo/America/St_Thomas
# rapids/share/zoneinfo/America/Nome
# rapids/share/zoneinfo/America/Shiprock
# rapids/share/zoneinfo/America/Matamoros
# rapids/share/zoneinfo/America/Punta_Arenas
# rapids/share/zoneinfo/America/Vancouver
# rapids/share/zoneinfo/America/Ensenada
# rapids/share/zoneinfo/America/Costa_Rica
# rapids/share/zoneinfo/America/Monterrey
# rapids/share/zoneinfo/America/Edmonton
# rapids/share/zoneinfo/America/Nassau
# rapids/share/zoneinfo/America/Bahia
# rapids/share/zoneinfo/America/Dawson_Creek
# rapids/share/zoneinfo/America/Detroit
# rapids/share/zoneinfo/America/Montreal
# rapids/share/zoneinfo/America/Sitka
# rapids/share/zoneinfo/America/Jamaica
# rapids/share/zoneinfo/America/Halifax
# rapids/share/zoneinfo/America/Goose_Bay
# rapids/share/zoneinfo/America/Sao_Paulo
# rapids/share/zoneinfo/America/Panama
# rapids/share/zoneinfo/America/Indiana/
# rapids/share/zoneinfo/America/Indiana/Indianapolis
# rapids/share/zoneinfo/America/Indiana/Petersburg
# rapids/share/zoneinfo/America/Indiana/Knox
# rapids/share/zoneinfo/America/Indiana/Marengo
# rapids/share/zoneinfo/America/Indiana/Tell_City
# rapids/share/zoneinfo/America/Indiana/Vevay
# rapids/share/zoneinfo/America/Indiana/Winamac
# rapids/share/zoneinfo/America/Indiana/Vincennes
# rapids/share/zoneinfo/Africa/
# rapids/share/zoneinfo/Africa/Kigali
# rapids/share/zoneinfo/Africa/Conakry
# rapids/share/zoneinfo/Africa/Luanda
# rapids/share/zoneinfo/Africa/Monrovia
# rapids/share/zoneinfo/Africa/Banjul
# rapids/share/zoneinfo/Africa/Nouakchott
# rapids/share/zoneinfo/Africa/Juba
# rapids/share/zoneinfo/Africa/Kampala
# rapids/share/zoneinfo/Africa/Addis_Ababa
# rapids/share/zoneinfo/Africa/Libreville
# rapids/share/zoneinfo/Africa/Bujumbura
# rapids/share/zoneinfo/Africa/El_Aaiun
# rapids/share/zoneinfo/Africa/Asmera
# rapids/share/zoneinfo/Africa/Ndjamena
# rapids/share/zoneinfo/Africa/Tunis
# rapids/share/zoneinfo/Africa/Mbabane
# rapids/share/zoneinfo/Africa/Djibouti
# rapids/share/zoneinfo/Africa/Nairobi
# rapids/share/zoneinfo/Africa/Lusaka
# rapids/share/zoneinfo/Africa/Malabo
# rapids/share/zoneinfo/Africa/Harare
# rapids/share/zoneinfo/Africa/Lubumbashi
# rapids/share/zoneinfo/Africa/Johannesburg
# rapids/share/zoneinfo/Africa/Dar_es_Salaam
# rapids/share/zoneinfo/Africa/Algiers
# rapids/share/zoneinfo/Africa/Windhoek
# rapids/share/zoneinfo/Africa/Maputo
# rapids/share/zoneinfo/Africa/Freetown
# rapids/share/zoneinfo/Africa/Casablanca
# rapids/share/zoneinfo/Africa/Timbuktu
# rapids/share/zoneinfo/Africa/Niamey
# rapids/share/zoneinfo/Africa/Asmara
# rapids/share/zoneinfo/Africa/Porto-Novo
# rapids/share/zoneinfo/Africa/Dakar
# rapids/share/zoneinfo/Africa/Ceuta
# rapids/share/zoneinfo/Africa/Bissau
# rapids/share/zoneinfo/Africa/Brazzaville
# rapids/share/zoneinfo/Africa/Lome
# rapids/share/zoneinfo/Africa/Abidjan
# rapids/share/zoneinfo/Africa/Mogadishu
# rapids/share/zoneinfo/Africa/Cairo
# rapids/share/zoneinfo/Africa/Ouagadougou
# rapids/share/zoneinfo/Africa/Maseru
# rapids/share/zoneinfo/Africa/Sao_Tome
# rapids/share/zoneinfo/Africa/Lagos
# rapids/share/zoneinfo/Africa/Khartoum
# rapids/share/zoneinfo/Africa/Accra
# rapids/share/zoneinfo/Africa/Gaborone
# rapids/share/zoneinfo/Africa/Kinshasa
# rapids/share/zoneinfo/Africa/Douala
# rapids/share/zoneinfo/Africa/Bangui
# rapids/share/zoneinfo/Africa/Blantyre
# rapids/share/zoneinfo/Africa/Tripoli
# rapids/share/zoneinfo/Africa/Bamako
# rapids/share/zoneinfo/Greenwich
# rapids/share/zoneinfo/Arctic/
# rapids/share/zoneinfo/Arctic/Longyearbyen
# rapids/share/zoneinfo/PRC
# rapids/share/zoneinfo/Kwajalein
# rapids/share/zoneinfo/MET
# rapids/share/zoneinfo/EST
# rapids/share/zoneinfo/Poland
# rapids/share/zoneinfo/Mexico/
# rapids/share/zoneinfo/Mexico/BajaNorte
# rapids/share/zoneinfo/Mexico/General
# rapids/share/zoneinfo/Mexico/BajaSur
# rapids/share/zoneinfo/Pacific/
# rapids/share/zoneinfo/Pacific/Pitcairn
# rapids/share/zoneinfo/Pacific/Guam
# rapids/share/zoneinfo/Pacific/Tarawa
# rapids/share/zoneinfo/Pacific/Fiji
# rapids/share/zoneinfo/Pacific/Marquesas
# rapids/share/zoneinfo/Pacific/Majuro
# rapids/share/zoneinfo/Pacific/Fakaofo
# rapids/share/zoneinfo/Pacific/Niue
# rapids/share/zoneinfo/Pacific/Pohnpei
# rapids/share/zoneinfo/Pacific/Norfolk
# rapids/share/zoneinfo/Pacific/Chatham
# rapids/share/zoneinfo/Pacific/Johnston
# rapids/share/zoneinfo/Pacific/Tongatapu
# rapids/share/zoneinfo/Pacific/Yap
# rapids/share/zoneinfo/Pacific/Pago_Pago
# rapids/share/zoneinfo/Pacific/Rarotonga
# rapids/share/zoneinfo/Pacific/Galapagos
# rapids/share/zoneinfo/Pacific/Kosrae
# rapids/share/zoneinfo/Pacific/Honolulu
# rapids/share/zoneinfo/Pacific/Easter
# rapids/share/zoneinfo/Pacific/Noumea
# rapids/share/zoneinfo/Pacific/Wallis
# rapids/share/zoneinfo/Pacific/Nauru
# rapids/share/zoneinfo/Pacific/Truk
# rapids/share/zoneinfo/Pacific/Midway
# rapids/share/zoneinfo/Pacific/Funafuti
# rapids/share/zoneinfo/Pacific/Efate
# rapids/share/zoneinfo/Pacific/Ponape
# rapids/share/zoneinfo/Pacific/Enderbury
# rapids/share/zoneinfo/Pacific/Gambier
# rapids/share/zoneinfo/Pacific/Chuuk
# rapids/share/zoneinfo/Pacific/Bougainville
# rapids/share/zoneinfo/Pacific/Tahiti
# rapids/share/zoneinfo/Pacific/Kwajalein
# rapids/share/zoneinfo/Pacific/Saipan
# rapids/share/zoneinfo/Pacific/Auckland
# rapids/share/zoneinfo/Pacific/Kiritimati
# rapids/share/zoneinfo/Pacific/Samoa
# rapids/share/zoneinfo/Pacific/Apia
# rapids/share/zoneinfo/Pacific/Guadalcanal
# rapids/share/zoneinfo/Pacific/Wake
# rapids/share/zoneinfo/Pacific/Port_Moresby
# rapids/share/zoneinfo/Pacific/Palau
# rapids/share/zoneinfo/GB
# rapids/share/zoneinfo/UTC
# rapids/share/zoneinfo/NZ
# rapids/share/zoneinfo/Indian/
# rapids/share/zoneinfo/Indian/Mayotte
# rapids/share/zoneinfo/Indian/Antananarivo
# rapids/share/zoneinfo/Indian/Kerguelen
# rapids/share/zoneinfo/Indian/Comoro
# rapids/share/zoneinfo/Indian/Maldives
# rapids/share/zoneinfo/Indian/Reunion
# rapids/share/zoneinfo/Indian/Christmas
# rapids/share/zoneinfo/Indian/Chagos
# rapids/share/zoneinfo/Indian/Mauritius
# rapids/share/zoneinfo/Indian/Cocos
# rapids/share/zoneinfo/Indian/Mahe
# rapids/share/zoneinfo/CST6CDT
# rapids/share/zoneinfo/Zulu
# rapids/share/zoneinfo/Portugal
# rapids/share/zoneinfo/Jamaica
# rapids/share/zoneinfo/HST
# rapids/share/zoneinfo/Chile/
# rapids/share/zoneinfo/Chile/Continental
# rapids/share/zoneinfo/Chile/EasterIsland
# rapids/share/errcodes.txt
# CPU times: user 2.63 s, sys: 1.22 s, total: 3.86 s
# Wall time: 57.8 s

# %%
import cudf,cuml
import pandas as pd
import numpy as np
from cuml.manifold import TSNE
from cuml import PCA  
#from cuml.decomposition import PCA << this is also supported
from cuml.cluster import DBSCAN
#from cuml import DBSCAN << this is also supported
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The following scatter function is defined below, but not used in this notebook. You could call it your self for some interesting visualizations

# %%
def scatter_thumbnails(data, images, zoom=0.12, colors=None):
    assert len(data) == len(images)

    # reduce embedding dimentions to 2
    x = PCA(n_components=2).fit_transform(data) if len(data[0]) > 2 else data

    # create a scatter plot.
    f = plt.figure(figsize=(22, 15))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], s=4)
    _ = ax.axis('off')
    _ = ax.axis('tight')

    # add thumbnails :) Displaying thumbnails is something I have commented out. 
#     from matplotlib.offsetbox import OffsetImage, AnnotationBbox
#     for i in range(len(images)):
#         image = plt.imread(images[i])
#         im = OffsetImage(image, zoom=zoom)
#         bboxprops = dict(edgecolor=colors[i]) if colors is not None else None
#         ab = AnnotationBbox(im, x[i], xycoords='data',
#                             frameon=(bboxprops is not None),
#                             pad=0.02,
#                             bboxprops=bboxprops)
#         ax.add_artist(ab)
    return ax

# %% [markdown]
# - Read pre-encoded embeddings. Created using the [original notebook](https://www.kaggle.com/skylord/face-clustering)>
# - This encodes the first-frame face crops, using the following codeblock
#
# ```
# from torchvision.transforms import ToTensor
#
# tf_img = lambda i: ToTensor()(i).unsqueeze(0)
# embeddings = lambda input: resnet(input)
#
# list_embs = []
# with torch.no_grad():
#     for face in tqdm(face_files):
#         t = tf_img(Image.open(face)).to(device)
#         e = embeddings(t).squeeze().cpu().tolist()
#         list_embs.append(e)
# ```

# %%
# %%time
import pickle

embeddings = pd.read_pickle('/kaggle/input/sample-face-crop/embeddings_face_clusters.pkl')
print(embeddings.shape)
embeddings.head()
# Out:
# (116573, 3)
# CPU times: user 5.07 s, sys: 1.25 s, total: 6.32 s
# Wall time: 6.69 s
#                                            embedding               faceFile  \
# 0  [0.06744061410427094, 0.007214107550680637, 0....  cnjssbpoun_frame0.jpg
# 1  [-0.057064350694417953, -0.015465210191905499,...  aupwvhmmzg_frame0.jpg
# 2  [-0.003266997169703245, -0.032444849610328674,...  twqwnsblvn_frame0.jpg
# 3  [-0.06885179132223129, 0.0053096953779459, -0....  zaicbihiam_frame0.jpg
# 4  [0.06825964897871017, -0.03303952515125275, -0...  hemhhjgnld_frame0.jpg
#
#    cluster
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4

# %%
# Convert the embeddings to columns
colnames = list()

for idx in range(512):
    colnames.append('colname_'+str(idx))
    
colnames;
embeddings[colnames] = pd.DataFrame(embeddings['embedding'].values.tolist(), index = embeddings.index)

# %%
#Convert to numpy array
embed_numpy = embeddings[colnames].to_numpy()

# %%
# %%time
# PCA first to speed it up
x = PCA(n_components=50).fit_transform(embed_numpy)
# Out:
# CPU times: user 2.38 s, sys: 1.05 s, total: 3.43 s
# Wall time: 3.6 s

# %% [markdown]
# Default dimensions for t-sne is n_components=2. This uses the fast Barnes-Hut clustering technique.
# With greater dimensions the exact method for calculating tsne is used

# %%
# %%time
tsne = TSNE(random_state = 99) # 
x = tsne.fit_transform(embed_numpy)
# Out:
# CPU times: user 4.17 s, sys: 3.38 s, total: 7.56 s
# Wall time: 7.7 s

# %% [markdown]
# Total time to fit the transform was ~ 7.35 secs !!!
#
# This can be compared to the 3-5+ hours if you used sklearn's t-sne

# %%
# %%time
tsne50 = TSNE(random_state=99, n_components=50)
x50= tsne50.fit_transform(embed_numpy)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Barnes Hut only works when n_components == 2. Switching to exact.
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Currently TSNE supports n_components = 2.
#   """Entry point for launching an IPython kernel.
# CPU times: user 1h 31min 52s, sys: 1h 43s, total: 2h 32min 35s
# Wall time: 2h 32min 46s

# %% [markdown]
# DBSCAN’s main benefit is that the number of clusters is not a hyperparameter, and that it can find non-linearly shaped clusters. This also allows DBSCAN to be robust to noise. DBSCAN has been applied to analyzing particle collisions in the Large Hadron Collider, customer segmentation in marketing analyses, and much more.

# %%
# %%time 
dbscan = DBSCAN(eps=1.5, verbose=True ) #min_samples (default is 5)
clusters =  dbscan.fit_predict(x)
embeddings['RapidDBSCAN'] = clusters
# Out:
# CPU times: user 16.4 s, sys: 611 ms, total: 17 s
# Wall time: 17.1 s

# %%
embeddings.to_pickle('/kaggle/working/embeddings.pkl')
